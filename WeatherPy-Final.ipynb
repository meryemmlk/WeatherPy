# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import API key

import api_keys
from api_keys import gkey


# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy
# Dependencies
import openweathermapy as owm

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
first_cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1550)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1550)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in first_cities:
        first_cities.append(city)

# Print the city count to confirm sufficient count
len(first_cities)
# Out:
# 652

# %% [markdown]
# ## Perform API Calls

# %%
# OpenWeatherMap API Key
api_key = api_keys.api_key

# Create settings dictionary with information we're interested in
settings = {"units": "imperial", "appid": api_key}

# Get current weather
weather_data = []
num = 0
cities = []
for city in first_cities:
    try:
        current_weather_city = owm.get_current(city, **settings)
        #print(f"Current weather object for {city}: {current_weather_city}.")
        summary = ["coord.lat", "coord.lon", "main.temp", "main.humidity", "clouds.all", "wind.speed"]
        data = current_weather_city(*summary)
        cities.append(city)
        num += 1
        print(f"The current weather summary city num:{num} for {city} is: {data}.")
        weather_data.append(data)
        #print(weather_data)
        
    except:
        print(f"Current city object for {city}: not found.")
        first_cities.remove(city)
        
#print(num)
#print(len(cities))
#print(len(first_cities))
# Out:
# The current weather summary city num:1 for faanui is: (-16.48, -151.75, 78.17, 100, 64, 21.83).
# The current weather summary city num:2 for albany is: (42.65, -73.75, 56.23, 89, 40, 2.15).
# The current weather summary city num:3 for castro is: (-42.48, -73.76, 40.1, 100, 0, 5.39).
# Current city object for bolungarvik: not found.
# The current weather summary city num:4 for palmer is: (-34.85, 139.16, 59, 44, 75, 13.87).
# The current weather summary city num:5 for vaini is: (15.34, 74.49, 75.11, 89, 0, 4.27).
# The current weather summary city num:6 for busselton is: (-33.64, 115.35, 68.27, 82, 76, 16.02).
# Current city object for grand river south east: not found.
# The current weather summary city num:7 for rikitea is: (-23.12, -134.97, 68.81, 100, 36, 19.26).
# The current weather summary city num:8 for ngunguru is: (-35.62, 174.5, 57.56, 100, 92, 13.67).
# The current weather summary city num:9 for unai is: (-16.36, -46.91, 76.28, 65, 44, 3.49).
# The current weather summary city num:10 for norman wells is: (65.28, -126.83, 30.2, 58, 75, 6.93).
# The current weather summary city num:11 for rio grande is: (-32.03, -52.1, 53.24, 100, 0, 4.5).
# The current weather summary city num:12 for den helder is: (52.96, 4.76, 59.61, 82, 90, 8.05).
# The current weather summary city num:13 for hobart is: (-42.88, 147.33, 53.6, 46, 40, 8.05).
# The current weather summary city num:14 for hilo is: (19.71, -155.08, 76.46, 65, 75, 11.41).
# The current weather summary city num:15 for sioux lookout is: (50.1, -91.92, 32, 100, 90, 20.8).
# The current weather summary city num:16 for mataura is: (-46.19, 168.86, 45.14, 100, 80, 7.18).
# Current city object for tocantinopolis: not found.
# The current weather summary city num:17 for jamestown is: (-33.21, 138.6, 56.03, 80, 0, 13).
# The current weather summary city num:18 for victoria is: (5.28, 115.24, 86, 79, 75, 4.7).
# The current weather summary city num:19 for vao is: (59.1, 26.19, 41.81, 91, 92, 15.23).
# The current weather summary city num:20 for yellowknife is: (62.45, -114.38, 24.8, 62, 90, 4.7).
# The current weather summary city num:21 for vredendal is: (-31.68, 18.49, 61.88, 32, 0, 8.08).
# The current weather summary city num:22 for san martin is: (37.08, -121.61, 68.74, 82, 40, 8.05).
# The current weather summary city num:23 for la ronge is: (55.1, -105.3, 28.4, 63, 40, 9.17).
# The current weather summary city num:24 for ambilobe is: (-13.19, 49.05, 72.41, 77, 36, 5.95).
# The current weather summary city num:25 for bethel is: (60.79, -161.76, 48.92, 89, 90, 12.75).
# Current city object for yingshang: not found.
# The current weather summary city num:26 for ishigaki is: (24.34, 124.16, 77, 94, 75, 19.46).
# Current city object for barentsburg: not found.
# Current city object for nizhneyansk: not found.
# The current weather summary city num:27 for east london is: (-33.02, 27.91, 60.53, 100, 88, 9.75).
# The current weather summary city num:28 for agde is: (43.31, 3.47, 58.01, 55, 0, 8.05).
# The current weather summary city num:29 for new norfolk is: (-42.78, 147.06, 53.6, 46, 40, 8.05).
# The current weather summary city num:30 for viransehir is: (37.24, 39.76, 51.44, 58, 0, 1.81).
# The current weather summary city num:31 for saint-philippe is: (45.36, -73.48, 51.62, 93, 90, 4.7).
# The current weather summary city num:32 for kruisfontein is: (-34, 24.73, 51.62, 97, 0, 4.05).
# The current weather summary city num:33 for kapaa is: (22.08, -159.32, 85.71, 69, 1, 13.87).
# The current weather summary city num:34 for geraldton is: (49.72, -86.95, 50, 100, 90, 4.7).
# The current weather summary city num:35 for tarazona is: (41.91, -1.72, 59.85, 63, 0, 13.87).
# The current weather summary city num:36 for ushuaia is: (-54.81, -68.31, 32, 92, 75, 13.87).
# The current weather summary city num:37 for qaanaaq is: (77.48, -69.36, 16.34, 100, 0, 15.57).
# The current weather summary city num:38 for tuktoyaktuk is: (69.44, -133.03, 23, 85, 75, 12.75).
# The current weather summary city num:39 for pontes e lacerda is: (-15.23, -59.33, 71.6, 97, 44, 2.37).
# The current weather summary city num:40 for jalu is: (29.03, 21.55, 81.41, 29, 36, 10.76).
# The current weather summary city num:41 for mar del plata is: (-46.43, -67.52, 49.91, 50, 32, 7.63).
# The current weather summary city num:42 for fort nelson is: (58.81, -122.69, 39.2, 41, 75, 8.05).
# Current city object for ksenyevka: not found.
# The current weather summary city num:43 for upernavik is: (72.79, -56.15, 30.11, 100, 68, 8.75).
# The current weather summary city num:44 for sistranda is: (63.73, 8.83, 42.8, 87, 75, 17.22).
# The current weather summary city num:45 for carnarvon is: (-30.97, 22.13, 37.13, 72, 0, 9.64).
# The current weather summary city num:46 for coquimbo is: (-29.95, -71.34, 53.6, 87, 0, 6.93).
# The current weather summary city num:47 for karasjok is: (69.47, 25.52, 37.4, 69, 0, 27.51).
# The current weather summary city num:48 for abu dhabi is: (24.47, 54.37, 83.34, 78, 0, 3.36).
# The current weather summary city num:49 for namatanai is: (-3.66, 152.44, 84.2, 100, 32, 7.4).
# The current weather summary city num:50 for bharatpur is: (27.68, 84.43, 72.5, 91, 24, 3.15).
# The current weather summary city num:51 for neiafu is: (-18.65, -173.98, 78.8, 83, 75, 16.11).
# The current weather summary city num:52 for esperance is: (10.24, -61.45, 80.6, 88, 20, 5.82).
# Current city object for krasnoselkup: not found.
# The current weather summary city num:53 for dindori is: (22.94, 81.08, 79.88, 57, 44, 3.71).
# The current weather summary city num:54 for alyangula is: (-13.85, 136.42, 83.93, 83, 0, 8.63).
# The current weather summary city num:55 for kangaatsiaq is: (68.31, -53.46, 33.98, 100, 24, 18.03).
# The current weather summary city num:56 for longyearbyen is: (78.22, 15.63, 32, 100, 75, 12.75).
# The current weather summary city num:57 for okhotsk is: (59.36, 143.24, 46.31, 82, 0, 6.4).
# The current weather summary city num:58 for nuuk is: (64.17, -51.74, 32, 100, 8, 4.7).
# Current city object for illoqqortoormiut: not found.
# The current weather summary city num:59 for xining is: (36.62, 101.77, 39.83, 79, 0, 3.27).
# The current weather summary city num:60 for auki is: (12.18, 6.51, 71.06, 88, 12, 6.73).
# The current weather summary city num:61 for port macquarie is: (-31.43, 152.91, 69.8, 64, 56, 4.7).
# The current weather summary city num:62 for port alfred is: (-33.59, 26.89, 59.54, 100, 64, 6.85).
# The current weather summary city num:63 for tasiilaq is: (65.61, -37.64, 30.2, 54, 56, 3.36).
# The current weather summary city num:64 for hermanus is: (-34.42, 19.24, 39.83, 94, 0, 4.27).
# The current weather summary city num:65 for ponta do sol is: (-20.63, -46, 66.47, 87, 68, 3.71).
# The current weather summary city num:66 for airai is: (-8.93, 125.41, 86.81, 42, 0, 1.14).
# The current weather summary city num:67 for puerto ayora is: (-0.74, -90.35, 70.43, 100, 0, 12.1).
# The current weather summary city num:68 for saint george is: (39.45, 22.34, 64.4, 88, 20, 3.36).
# The current weather summary city num:69 for necochea is: (-38.55, -58.74, 44.42, 89, 20, 7.74).
# The current weather summary city num:70 for chimbote is: (-9.08, -78.59, 62.6, 94, 68, 4.16).
# The current weather summary city num:71 for athabasca is: (54.72, -113.29, 23.63, 74, 12, 2.93).
# The current weather summary city num:72 for acari is: (-6.44, -36.64, 70.61, 83, 0, 10.31).
# The current weather summary city num:73 for punta arenas is: (-53.16, -70.91, 41, 75, 40, 14.99).
# The current weather summary city num:74 for grindavik is: (63.84, -22.43, 39.92, 80, 90, 20.8).
# Current city object for kapoeta: not found.
# The current weather summary city num:75 for souillac is: (45.6, -0.6, 51.8, 87, 0, 3.36).
# The current weather summary city num:76 for bulawayo is: (-20.16, 28.59, 55.94, 67, 0, 11.77).
# Current city object for dolbeau: not found.
# The current weather summary city num:77 for chuy is: (-33.69, -53.46, 51.8, 89, 56, 5.17).
# The current weather summary city num:78 for atuona is: (-9.8, -139.03, 79.34, 100, 0, 14.45).
# The current weather summary city num:79 for bluff is: (-23.58, 149.07, 84.92, 30, 12, 5.39).
# The current weather summary city num:80 for cururupu is: (-1.82, -44.87, 79.43, 77, 76, 8.75).
# The current weather summary city num:81 for cape town is: (-33.93, 18.42, 51.8, 71, 0, 8.05).
# The current weather summary city num:82 for tura is: (25.52, 90.21, 76.01, 97, 56, 3.38).
# The current weather summary city num:83 for fereydunshahr is: (32.94, 50.12, 35.33, 76, 0, 2.37).
# The current weather summary city num:84 for lebu is: (8.96, 38.73, 51.8, 76, 20, 4.7).
# The current weather summary city num:85 for buncrana is: (55.14, -7.45, 56.12, 93, 80, 16.13).
# The current weather summary city num:86 for cap malheureux is: (-19.98, 57.61, 60.8, 82, 20, 9.17).
# The current weather summary city num:87 for kavieng is: (-2.57, 150.8, 85.73, 100, 24, 4.38).
# The current weather summary city num:88 for bedele is: (8.46, 36.35, 56.66, 100, 100, 2.93).
# The current weather summary city num:89 for bolobo is: (-2.17, 16.23, 72.59, 95, 44, 3.6).
# The current weather summary city num:90 for mahebourg is: (-20.41, 57.7, 60.8, 82, 20, 9.17).
# The current weather summary city num:91 for encruzilhada do sul is: (-30.54, -52.52, 46.49, 89, 12, 4.61).
# The current weather summary city num:92 for morondava is: (-20.3, 44.28, 65.84, 100, 0, 4.94).
# The current weather summary city num:93 for itapirapua is: (-15.82, -50.61, 75.83, 74, 12, 2.71).
# The current weather summary city num:94 for ramanuj ganj is: (23.81, 83.7, 82.94, 75, 8, 4.38).
# The current weather summary city num:95 for grand-santi is: (4.27, -54.38, 82.67, 65, 0, 4.72).
# The current weather summary city num:96 for provideniya is: (64.42, -173.23, 50, 81, 90, 13.42).
# The current weather summary city num:97 for ikryanoye is: (46.1, 47.74, 59, 87, 8, 4.47).
# The current weather summary city num:98 for naraina is: (26.78, 75.2, 77, 61, 40, 4.38).
# The current weather summary city num:99 for mandera is: (3.94, 41.86, 75.38, 62, 0, 11.43).
# Current city object for tsihombe: not found.
# The current weather summary city num:100 for aklavik is: (68.22, -135.01, 26.6, 73, 90, 12.75).
# The current weather summary city num:101 for brownwood is: (31.71, -98.99, 78.17, 54, 20, 8.05).
# The current weather summary city num:102 for arlit is: (18.74, 7.39, 72.23, 41, 8, 2.82).
# The current weather summary city num:103 for saint-georges is: (46.12, -70.67, 40.46, 89, 48, 2.82).
# The current weather summary city num:104 for turukhansk is: (65.8, 87.96, 33.35, 93, 76, 18.92).
# The current weather summary city num:105 for kaitangata is: (-46.28, 169.85, 46.04, 100, 92, 12.21).
# The current weather summary city num:106 for richards bay is: (-28.77, 32.06, 57.83, 99, 100, 13.89).
# The current weather summary city num:107 for inuvik is: (68.36, -133.71, 26.6, 73, 90, 12.75).
# The current weather summary city num:108 for ambovombe is: (-25.18, 46.09, 63.86, 100, 0, 6.4).
# The current weather summary city num:109 for nikolskoye is: (59.7, 30.79, 42.8, 87, 75, 11.18).
# The current weather summary city num:110 for evensk is: (61.92, 159.24, 47.12, 91, 20, 14).
# The current weather summary city num:111 for murashi is: (59.4, 48.97, 46.13, 98, 92, 8.63).
# The current weather summary city num:112 for kirakira is: (-10.46, 161.92, 82.22, 100, 8, 11.99).
# The current weather summary city num:113 for kahului is: (20.89, -156.47, 82.56, 67, 40, 17.22).
# The current weather summary city num:114 for leningradskiy is: (69.38, 178.42, 40.37, 87, 24, 11.32).
# The current weather summary city num:115 for vestmanna is: (62.16, -7.17, 48.2, 93, 88, 13.87).
# The current weather summary city num:116 for talara is: (-4.58, -81.27, 67.28, 86, 88, 6.96).
# The current weather summary city num:117 for cidreira is: (-30.17, -50.22, 54.86, 92, 24, 4.61).
# The current weather summary city num:118 for saskylakh is: (71.97, 114.09, 29.93, 92, 64, 12.44).
# Current city object for amderma: not found.
# The current weather summary city num:119 for san cristobal is: (-0.39, -78.55, 53.6, 87, 75, 3.36).
# The current weather summary city num:120 for avarua is: (-21.21, -159.78, 77, 47, 40, 13.87).
# The current weather summary city num:121 for port hardy is: (50.7, -127.42, 48.2, 70, 75, 4.7).
# The current weather summary city num:122 for puerto del rosario is: (28.5, -13.86, 72.59, 73, 0, 4.7).
# The current weather summary city num:123 for dikson is: (73.51, 80.55, 38.03, 100, 76, 19.04).
# The current weather summary city num:124 for hobyo is: (5.35, 48.53, 75.38, 93, 12, 12.33).
# The current weather summary city num:125 for nanortalik is: (60.14, -45.24, 35.78, 96, 24, 20.49).
# The current weather summary city num:126 for sosnovo-ozerskoye is: (52.53, 111.54, 52.61, 63, 0, 5.39).
# The current weather summary city num:127 for san vicente is: (13.64, -88.78, 79.7, 83, 0, 2.24).
# The current weather summary city num:128 for atasu is: (48.68, 71.64, 40.1, 60, 0, 5.95).
# The current weather summary city num:129 for yulara is: (-25.24, 130.99, 73.4, 38, 0, 14.99).
# The current weather summary city num:130 for sarahan is: (31.51, 77.79, 26.78, 86, 80, 0.69).
# The current weather summary city num:131 for mutis is: (6.23, -77.4, 77.18, 100, 92, 4.05).
# The current weather summary city num:132 for benguela is: (-12.58, 13.4, 68.63, 99, 0, 2.71).
# The current weather summary city num:133 for maniitsoq is: (65.42, -52.9, 31.46, 100, 88, 5.28).
# The current weather summary city num:134 for dunedin is: (-45.87, 170.5, 55.58, 86, 100, 8.08).
# The current weather summary city num:135 for los llanos de aridane is: (28.66, -17.92, 71.6, 78, 68, 6.93).
# The current weather summary city num:136 for codrington is: (-28.95, 153.24, 76.91, 62, 76, 3.38).
# Current city object for labutta: not found.
# The current weather summary city num:137 for vazante is: (-17.99, -46.9, 69.08, 85, 48, 2.37).
# The current weather summary city num:138 for goderich is: (43.74, -81.71, 67.37, 90, 20, 23.96).
# The current weather summary city num:139 for romny is: (50.74, 33.49, 44.69, 89, 88, 19.26).
# Current city object for belushya guba: not found.
# The current weather summary city num:140 for lorengau is: (-2.02, 147.27, 84.47, 100, 24, 2.59).
# The current weather summary city num:141 for espinosa is: (-14.92, -42.81, 73.49, 56, 8, 8.3).
# The current weather summary city num:142 for eyl is: (7.98, 49.82, 73.94, 98, 24, 11.21).
# The current weather summary city num:143 for nome is: (30.04, -94.42, 78.57, 95, 1, 4.38).
# The current weather summary city num:144 for san patricio is: (-26.98, -56.83, 65.21, 85, 8, 7.85).
# The current weather summary city num:145 for lubao is: (14.94, 120.6, 83.64, 78, 75, 4.7).
# The current weather summary city num:146 for sokoto is: (13.06, 5.24, 72.68, 87, 36, 1.92).
# The current weather summary city num:147 for hofn is: (64.25, -15.21, 45.59, 100, 92, 15.9).
# The current weather summary city num:148 for sakaiminato is: (35.55, 133.23, 70.63, 56, 75, 17.22).
# The current weather summary city num:149 for anshun is: (26.25, 105.93, 56.48, 88, 88, 4.61).
# The current weather summary city num:150 for port elizabeth is: (39.31, -74.98, 65.93, 90, 1, 3.36).
# The current weather summary city num:151 for narsaq is: (60.91, -46.05, 35.6, 55, 12, 5.82).
# The current weather summary city num:152 for thompson is: (55.74, -97.86, 30.2, 54, 40, 13.87).
# The current weather summary city num:153 for piqua is: (40.14, -84.24, 75.38, 73, 1, 14.99).
# The current weather summary city num:154 for torbay is: (47.66, -52.73, 44.6, 81, 90, 12.75).
# The current weather summary city num:155 for georgetown is: (6.8, -58.16, 77, 94, 0, 4.7).
# The current weather summary city num:156 for portland is: (45.52, -122.67, 59.83, 44, 90, 5.82).
# The current weather summary city num:157 for prince rupert is: (54.32, -130.32, 51.8, 50, 1, 4.7).
# The current weather summary city num:158 for ormara is: (25.21, 64.64, 78.62, 80, 0, 5.95).
# The current weather summary city num:159 for jutai is: (-1.71, -47.89, 77, 86, 24, 6.29).
# The current weather summary city num:160 for leirvik is: (59.78, 5.5, 46.4, 87, 92, 12.75).
# The current weather summary city num:161 for chapais is: (49.78, -74.86, 46.4, 93, 90, 16.11).
# The current weather summary city num:162 for awjilah is: (29.14, 21.3, 82.67, 29, 76, 11.54).
# The current weather summary city num:163 for nelson bay is: (-32.72, 152.14, 64.4, 100, 90, 18.34).
# The current weather summary city num:164 for kyren is: (51.68, 102.13, 25.16, 69, 88, 3.6).
# The current weather summary city num:165 for tigil is: (57.8, 158.67, 43.7, 92, 92, 9.42).
# The current weather summary city num:166 for tiksi is: (71.64, 128.87, 28.13, 96, 12, 4.83).
# The current weather summary city num:167 for hami is: (42.84, 93.51, 56.21, 43, 0, 5.73).
# The current weather summary city num:168 for qeshm is: (26.96, 56.27, 83.34, 83, 20, 4.7).
# The current weather summary city num:169 for chokurdakh is: (70.62, 147.9, 31.73, 100, 80, 11.1).
# The current weather summary city num:170 for rio gallegos is: (-51.62, -69.22, 42.8, 60, 20, 25.28).
# The current weather summary city num:171 for sisimiut is: (66.94, -53.67, 28.4, 94, 88, 4.38).
# Current city object for skalistyy: not found.
# The current weather summary city num:172 for mulki is: (49.81, 20.51, 44.6, 87, 40, 11.41).
# The current weather summary city num:173 for yabrud is: (33.97, 36.66, 66.2, 48, 0, 4.7).
# The current weather summary city num:174 for woodstock is: (43.13, -80.75, 58.96, 93, 20, 8.05).
# The current weather summary city num:175 for same is: (-9, 125.65, 86.81, 42, 0, 1.14).
# The current weather summary city num:176 for turayf is: (31.68, 38.65, 75.2, 29, 40, 4.7).
# The current weather summary city num:177 for lavrentiya is: (65.58, -170.99, 47.03, 87, 92, 21.83).
# The current weather summary city num:178 for severo-yeniseyskiy is: (60.37, 93.04, 34.61, 87, 80, 3.15).
# Current city object for samusu: not found.
# The current weather summary city num:179 for hithadhoo is: (-0.6, 73.08, 83.03, 100, 80, 23.06).
# The current weather summary city num:180 for cherskiy is: (68.75, 161.3, 36.05, 88, 88, 7.18).
# Current city object for mouzakion: not found.
# The current weather summary city num:181 for tessalit is: (20.2, 1.01, 66.2, 30, 0, 8.19).
# The current weather summary city num:182 for caravelas is: (-17.73, -39.27, 77.36, 100, 36, 16.58).
# The current weather summary city num:183 for kijang is: (35.24, 129.21, 71.6, 64, 75, 13.87).
# Current city object for vaitupu: not found.
# The current weather summary city num:184 for russell is: (-33.01, -68.8, 59, 51, 0, 3.36).
# The current weather summary city num:185 for butaritari is: (3.07, 172.79, 85.1, 100, 8, 6.4).
# The current weather summary city num:186 for bandarbeyla is: (9.49, 50.81, 76.1, 98, 12, 4.94).
# The current weather summary city num:187 for arraial do cabo is: (-22.97, -42.02, 75.2, 83, 75, 3.36).
# The current weather summary city num:188 for kupang is: (-10.16, 123.6, 87.8, 52, 20, 4.7).
# The current weather summary city num:189 for luderitz is: (-26.65, 15.16, 66.2, 53, 0, 23.73).
# The current weather summary city num:190 for sinnamary is: (5.38, -52.96, 82.04, 92, 0, 12.66).
# The current weather summary city num:191 for rudkobing is: (54.94, 10.71, 50, 87, 48, 6.93).
# The current weather summary city num:192 for altagracia de orituco is: (9.86, -66.38, 76.82, 80, 56, 7.85).
# The current weather summary city num:193 for grand-lahou is: (5.24, -5, 74.3, 97, 80, 3.71).
# The current weather summary city num:194 for liwale is: (-9.8, 37.92, 67.28, 84, 92, 3.04).
# The current weather summary city num:195 for tuatapere is: (-46.13, 167.69, 46.94, 100, 68, 9.86).
# The current weather summary city num:196 for klaksvik is: (62.23, -6.59, 48.2, 93, 92, 16.11).
# The current weather summary city num:197 for fortuna is: (38.18, -1.13, 61.81, 82, 0, 2.24).
# The current weather summary city num:198 for berlin is: (52.52, 13.39, 46.4, 87, 0, 8.05).
# The current weather summary city num:199 for makakilo city is: (21.35, -158.09, 84.49, 59, 75, 9.17).
# The current weather summary city num:200 for kotido is: (3.01, 34.12, 60.35, 89, 0, 7.29).
# The current weather summary city num:201 for svencionys is: (55.15, 26.17, 42.08, 96, 92, 26.08).
# The current weather summary city num:202 for salalah is: (17.01, 54.1, 73.4, 78, 0, 3.36).
# The current weather summary city num:203 for pirovskoye is: (57.63, 92.27, 40.46, 91, 76, 5.17).
# The current weather summary city num:204 for peniche is: (39.36, -9.38, 61.7, 28, 0, 3.36).
# The current weather summary city num:205 for aripuana is: (-9.17, -60.63, 76.1, 94, 8, 2.04).
# The current weather summary city num:206 for faya is: (18.39, 42.45, 64.4, 34, 0, 2.71).
# The current weather summary city num:207 for isangel is: (-19.55, 169.27, 73.31, 100, 76, 9.64).
# The current weather summary city num:208 for kitaibaraki is: (36.84, 140.74, 64.4, 77, 75, 3.36).
# The current weather summary city num:209 for togur is: (58.36, 82.83, 46.85, 68, 80, 12.1).
# The current weather summary city num:210 for churu is: (28.3, 74.97, 77.36, 55, 24, 4.61).
# The current weather summary city num:211 for umm lajj is: (25.02, 37.27, 76.46, 100, 0, 1.92).
# The current weather summary city num:212 for miandrivazo is: (-19.53, 45.46, 58.64, 78, 0, 2.26).
# Current city object for ngukurr: not found.
# The current weather summary city num:213 for saint-francois is: (46.42, 3.91, 46.4, 93, 90, 4.94).
# The current weather summary city num:214 for kihei is: (20.76, -156.45, 82.6, 67, 40, 17.22).
# Current city object for umzimvubu: not found.
# The current weather summary city num:215 for byron bay is: (-28.65, 153.62, 75.2, 60, 32, 18.34).
# The current weather summary city num:216 for bacabal is: (-4.23, -44.78, 77.81, 76, 0, 11.1).
# Current city object for liapades: not found.
# The current weather summary city num:217 for vila velha is: (-3.71, -38.6, 78.8, 78, 20, 10.29).
# The current weather summary city num:218 for beringovskiy is: (63.05, 179.32, 46.22, 99, 92, 16.24).
# The current weather summary city num:219 for nabire is: (-3.36, 135.5, 76.28, 88, 80, 1.14).
# The current weather summary city num:220 for ekimchan is: (53.07, 132.94, 55.76, 42, 0, 5.95).
# Current city object for olafsvik: not found.
# The current weather summary city num:221 for kapit is: (2.02, 112.94, 83.93, 80, 24, 2.93).
# The current weather summary city num:222 for rocha is: (-34.48, -54.34, 47.84, 60, 0, 4.16).
# Current city object for sentyabrskiy: not found.
# The current weather summary city num:223 for gizo is: (31.8, 34.94, 77, 78, 40, 2.24).
# The current weather summary city num:224 for cockburn town is: (21.46, -71.14, 82.4, 100, 64, 9.42).
# The current weather summary city num:225 for sorland is: (67.67, 12.69, 42.71, 100, 56, 6.62).
# The current weather summary city num:226 for seguin is: (29.57, -97.96, 78.78, 79, 1, 5.82).
# The current weather summary city num:227 for cayenne is: (4.94, -52.33, 77, 100, 40, 8.52).
# The current weather summary city num:228 for sao joao da barra is: (-21.64, -41.05, 75.2, 83, 0, 6.93).
# The current weather summary city num:229 for hasaki is: (35.73, 140.83, 72.37, 64, 75, 13.87).
# The current weather summary city num:230 for la palma del condado is: (37.38, -6.55, 68, 68, 0, 3.36).
# The current weather summary city num:231 for clyde river is: (70.47, -68.59, 30.2, 92, 90, 2.24).
# The current weather summary city num:232 for filadelfia is: (-22.35, -60.04, 66.74, 89, 92, 8.52).
# The current weather summary city num:233 for urucara is: (-2.54, -57.76, 79.25, 77, 0, 4.38).
# The current weather summary city num:234 for ilulissat is: (69.22, -51.1, 23, 73, 80, 4.61).
# The current weather summary city num:235 for harrison is: (39.26, -84.82, 75.72, 73, 1, 3.36).
# The current weather summary city num:236 for seversk is: (56.6, 84.88, 46.4, 67, 80, 6.4).
# The current weather summary city num:237 for shreveport is: (32.52, -93.77, 78.57, 89, 1, 4.72).
# The current weather summary city num:238 for deputatskiy is: (69.3, 139.9, 28.58, 89, 24, 4.05).
# The current weather summary city num:239 for taseyevo is: (57.22, 94.9, 40.46, 83, 92, 6.06).
# The current weather summary city num:240 for teahupoo is: (-17.83, -149.27, 82.4, 58, 40, 9.17).
# The current weather summary city num:241 for taltal is: (-25.41, -70.49, 55.31, 93, 76, 1.36).
# The current weather summary city num:242 for bathsheba is: (13.22, -59.52, 82.4, 78, 40, 10.29).
# The current weather summary city num:243 for kropotkin is: (45.43, 40.58, 59.54, 95, 92, 7.85).
# The current weather summary city num:244 for kokopo is: (-4.34, 152.27, 80.69, 100, 68, 3.04).
# The current weather summary city num:245 for vostok is: (46.45, 135.83, 60.8, 49, 0, 2.82).
# The current weather summary city num:246 for zhigansk is: (66.77, 123.37, 35.15, 100, 92, 3.83).
# The current weather summary city num:247 for roma is: (41.89, 12.48, 63.34, 72, 0, 5.82).
# Current city object for hurghada: not found.
# The current weather summary city num:248 for bambous virieux is: (-20.34, 57.76, 60.8, 82, 20, 9.17).
# The current weather summary city num:249 for sebinkarahisar is: (40.29, 38.42, 35.33, 86, 0, 2.15).
# The current weather summary city num:250 for aginskoye is: (51.11, 114.54, 57.74, 40, 48, 4.72).
# The current weather summary city num:251 for redlands is: (34.06, -117.19, 74.61, 64, 75, 5.82).
# The current weather summary city num:252 for flinders is: (-34.58, 150.85, 55.4, 100, 90, 10.29).
# The current weather summary city num:253 for dawson creek is: (55.76, -120.23, 38.84, 41, 1, 8.05).
# The current weather summary city num:254 for zhezkazgan is: (47.8, 67.71, 39.2, 48, 0, 8.95).
# The current weather summary city num:255 for havelock is: (34.88, -76.9, 75.87, 87, 1, 4.7).
# The current weather summary city num:256 for mumbwa is: (-14.99, 27.06, 63.95, 62, 0, 8.97).
# The current weather summary city num:257 for ulladulla is: (-35.36, 150.48, 55.4, 100, 90, 10.29).
# The current weather summary city num:258 for kabinda is: (-6.14, 24.49, 68.09, 97, 64, 3.38).
# The current weather summary city num:259 for nador is: (35.17, -2.93, 59, 77, 0, 3.36).
# The current weather summary city num:260 for nyurba is: (63.29, 118.35, 41.36, 64, 76, 7.96).
# The current weather summary city num:261 for guanica is: (17.97, -66.91, 77, 100, 1, 4.7).
# The current weather summary city num:262 for margate is: (-43.03, 147.26, 53.6, 46, 40, 8.05).
# The current weather summary city num:263 for lompoc is: (34.64, -120.46, 67.39, 72, 90, 5.82).
# The current weather summary city num:264 for vangaindrano is: (-23.35, 47.6, 65.93, 88, 100, 2.93).
# The current weather summary city num:265 for kamennogorsk is: (60.95, 29.13, 37.4, 90, 75, 10.29).
# The current weather summary city num:266 for chabahar is: (25.29, 60.65, 79.43, 100, 0, 4.38).
# The current weather summary city num:267 for kazaki is: (52.62, 38.27, 43.52, 97, 80, 14.12).
# The current weather summary city num:268 for verkhoyansk is: (67.55, 133.39, 28.31, 69, 56, 3.6).
# The current weather summary city num:269 for bontang is: (0.12, 117.47, 81.59, 100, 76, 4.05).
# The current weather summary city num:270 for itacarambi is: (-15.1, -44.09, 80.51, 54, 44, 7.4).
# The current weather summary city num:271 for port augusta is: (-32.49, 137.76, 57.2, 62, 90, 14.99).
# The current weather summary city num:272 for mayumba is: (-3.44, 10.65, 74.93, 100, 92, 5.73).
# The current weather summary city num:273 for coihaique is: (-45.58, -72.07, 42.8, 70, 0, 4.7).
# The current weather summary city num:274 for ribeira grande is: (38.52, -28.7, 72.32, 99, 76, 10.76).
# The current weather summary city num:275 for mayo is: (63.59, -135.9, 41, 35, 75, 2.24).
# The current weather summary city num:276 for tarakan is: (3.3, 117.63, 87.62, 80, 8, 1.59).
# The current weather summary city num:277 for khani is: (41.96, 42.96, 60.8, 93, 75, 3.36).
# The current weather summary city num:278 for sri aman is: (1.24, 111.46, 80.6, 88, 75, 2.24).
# The current weather summary city num:279 for vesoul is: (47.62, 6.16, 42.8, 100, 90, 2.24).
# The current weather summary city num:280 for kodiak is: (39.95, -94.76, 84.02, 62, 1, 10.29).
# Current city object for karauzyak: not found.
# The current weather summary city num:281 for urusha is: (54.05, 122.9, 57.2, 48, 0, 3.6).
# The current weather summary city num:282 for plettenberg bay is: (-34.05, 23.37, 56.3, 100, 0, 6.4).
# The current weather summary city num:283 for pangkalanbuun is: (-2.68, 111.62, 86.09, 82, 20, 6.73).
# The current weather summary city num:284 for klyuchi is: (52.25, 79.17, 44.96, 68, 0, 8.63).
# The current weather summary city num:285 for belyy yar is: (53.6, 91.39, 41, 86, 40, 4.47).
# The current weather summary city num:286 for marion is: (35.21, -90.2, 78.24, 76, 1, 8.05).
# The current weather summary city num:287 for roald is: (62.58, 6.12, 43.34, 65, 92, 8.05).
# The current weather summary city num:288 for dhuri is: (30.37, 75.86, 74.3, 83, 20, 3.27).
# The current weather summary city num:289 for yeppoon is: (-23.13, 150.74, 80.6, 39, 0, 6.93).
# The current weather summary city num:290 for sao francisco de paula is: (-29.45, -50.58, 53.87, 99, 88, 2.59).
# The current weather summary city num:291 for luebo is: (-5.35, 21.42, 70.61, 93, 48, 1.59).
# Current city object for tubruq: not found.
# The current weather summary city num:292 for obama is: (35.49, 135.74, 68.09, 87, 100, 3.49).
# The current weather summary city num:293 for amapa is: (15.09, -87.97, 77, 94, 75, 2.24).
# Current city object for saleaula: not found.
# The current weather summary city num:294 for vardo is: (39.62, -77.74, 68.72, 93, 1, 2.82).
# The current weather summary city num:295 for digby is: (44.62, -65.76, 62.24, 92, 92, 7.74).
# The current weather summary city num:296 for port hedland is: (-20.31, 118.58, 95, 19, 0, 11.41).
# Current city object for cozumel: not found.
# The current weather summary city num:297 for mount gambier is: (-37.83, 140.78, 58.91, 66, 0, 8.19).
# The current weather summary city num:298 for mosquera is: (4.71, -74.23, 59, 72, 75, 5.82).
# The current weather summary city num:299 for hualmay is: (-11.1, -77.61, 59.18, 94, 24, 3.04).
# Current city object for uzumlu: not found.
# Current city object for bengkulu: not found.
# The current weather summary city num:300 for skjervoy is: (70.03, 20.97, 39.29, 100, 88, 11.65).
# The current weather summary city num:301 for macas is: (-2.3, -78.12, 62.96, 86, 12, 2.59).
# The current weather summary city num:302 for zaozerne is: (51.37, 23.94, 44.96, 81, 56, 20.27).
# The current weather summary city num:303 for jiexiu is: (37.02, 111.92, 64.67, 51, 0, 4.27).
# The current weather summary city num:304 for pevek is: (69.7, 170.27, 40.73, 100, 68, 6.51).
# The current weather summary city num:305 for woodland is: (45.91, -122.74, 61.2, 53, 1, 8.05).
# The current weather summary city num:306 for fraijanes is: (14.47, -90.43, 68, 82, 40, 11.41).
# The current weather summary city num:307 for kambove is: (-10.88, 26.6, 62.42, 55, 8, 4.05).
# The current weather summary city num:308 for rapar is: (23.57, 70.65, 73.49, 84, 12, 4.5).
# The current weather summary city num:309 for tarija is: (-21.53, -64.73, 59, 72, 75, 5.82).
# The current weather summary city num:310 for severo-kurilsk is: (50.68, 156.12, 47.3, 96, 56, 21.83).
# The current weather summary city num:311 for livingstonia is: (-10.61, 34.11, 69.08, 86, 100, 2.15).
# The current weather summary city num:312 for tyrma is: (50.04, 132.17, 61.52, 54, 0, 4.94).
# The current weather summary city num:313 for saint-marc is: (19.1, -72.7, 75.38, 93, 92, 2.93).
# The current weather summary city num:314 for yicheng is: (31.71, 112.27, 73.94, 62, 0, 4.94).
# The current weather summary city num:315 for ballitoville is: (-29.54, 31.21, 55.31, 96, 88, 13).
# The current weather summary city num:316 for north bend is: (43.41, -124.22, 53.76, 80, 1, 6.93).
# The current weather summary city num:317 for frontera is: (18.53, -92.64, 80.6, 78, 75, 5.82).
# The current weather summary city num:318 for bien hoa is: (10.95, 106.82, 80.6, 94, 40, 3.36).
# The current weather summary city num:319 for duluth is: (46.77, -92.13, 50.31, 81, 75, 29.97).
# The current weather summary city num:320 for nexo is: (55.06, 15.13, 50, 81, 36, 17.22).
# The current weather summary city num:321 for mattru is: (7.62, -11.83, 74.03, 99, 56, 2.48).
# The current weather summary city num:322 for parauna is: (-3.82, 122.09, 83.03, 55, 48, 2.37).
# The current weather summary city num:323 for soe is: (57.91, 26.05, 42.8, 87, 90, 13.87).
# Current city object for rudbar: not found.
# The current weather summary city num:324 for turia is: (50.89, 35.35, 43.88, 91, 92, 17.69).
# The current weather summary city num:325 for norsup is: (-16.07, 167.38, 80.15, 75, 0, 2.93).
# The current weather summary city num:326 for khatanga is: (71.98, 102.47, 30.56, 94, 64, 11.99).
# The current weather summary city num:327 for samarai is: (-10.62, 150.67, 77.63, 100, 44, 12.77).
# The current weather summary city num:328 for bubaque is: (11.28, -15.83, 80.24, 100, 80, 13).
# The current weather summary city num:329 for bosaso is: (11.28, 49.18, 81.5, 100, 0, 7.29).
# The current weather summary city num:330 for camalu is: (30.85, -116.07, 60.53, 98, 0, 3.71).
# The current weather summary city num:331 for quelimane is: (-17.88, 36.89, 66.74, 92, 0, 3.94).
# The current weather summary city num:332 for solwezi is: (-12.18, 26.4, 62.15, 62, 24, 4.27).
# The current weather summary city num:333 for san jose is: (15.79, 120.99, 81.41, 86, 8, 3.04).
# The current weather summary city num:334 for seoul is: (37.57, 126.98, 68.72, 63, 40, 10.29).
# The current weather summary city num:335 for aguimes is: (27.91, -15.45, 71.6, 83, 20, 11.41).
# The current weather summary city num:336 for kolpashevo is: (58.31, 82.9, 46.85, 68, 80, 12.1).
# The current weather summary city num:337 for brandenburg is: (38, -86.17, 77.59, 85, 1, 4.7).
# The current weather summary city num:338 for kununurra is: (-15.77, 128.74, 95, 34, 0, 8.05).
# The current weather summary city num:339 for henties bay is: (-22.12, 14.28, 59.63, 91, 0, 7.96).
# The current weather summary city num:340 for minab is: (27.15, 57.07, 82.4, 83, 20, 4.7).
# The current weather summary city num:341 for guiyang is: (26.58, 106.71, 55.4, 82, 90, 4.47).
# The current weather summary city num:342 for skibbereen is: (51.55, -9.27, 53.6, 100, 75, 6.93).
# The current weather summary city num:343 for ciudad bolivar is: (8.12, -63.55, 85.46, 57, 20, 12.88).
# Current city object for jiddah: not found.
# The current weather summary city num:344 for port blair is: (11.67, 92.75, 86.81, 94, 8, 6.96).
# The current weather summary city num:345 for yerbogachen is: (61.28, 108.01, 38.84, 61, 64, 6.73).
# Current city object for naftah: not found.
# The current weather summary city num:346 for meulaboh is: (4.14, 96.13, 77.27, 100, 92, 3.15).
# The current weather summary city num:347 for port lincoln is: (-34.72, 135.86, 57.29, 91, 8, 13.78).
# The current weather summary city num:348 for sobolevo is: (54.43, 31.9, 43.52, 98, 88, 14.45).
# The current weather summary city num:349 for komsomolskiy is: (67.55, 63.78, 40.28, 95, 92, 15.01).
# The current weather summary city num:350 for canutama is: (-6.53, -64.38, 76.1, 94, 0, 2.26).
# Current city object for karkaralinsk: not found.
# The current weather summary city num:351 for saldanha is: (41.42, -6.55, 46.31, 86, 0, 4.61).
# The current weather summary city num:352 for berdigestyakh is: (62.1, 126.7, 41, 64, 0, 5.5).
# The current weather summary city num:353 for sitka is: (37.17, -99.65, 73.58, 82, 56, 5.5).
# The current weather summary city num:354 for dubbo is: (-32.25, 148.6, 62.6, 82, 90, 12.75).
# The current weather summary city num:355 for bilma is: (18.69, 12.92, 73.04, 32, 0, 2.59).
# The current weather summary city num:356 for vallenar is: (-28.58, -70.76, 55.31, 68, 80, 2.59).
# The current weather summary city num:357 for paamiut is: (61.99, -49.67, 35.6, 100, 12, 4.5).
# Current city object for tawkar: not found.
# The current weather summary city num:358 for cileunyi is: (-6.94, 107.75, 76.82, 70, 0, 2.71).
# The current weather summary city num:359 for inhambane is: (-23.87, 35.38, 68, 100, 8, 10.31).
# The current weather summary city num:360 for mocorito is: (25.48, -107.92, 85.19, 66, 24, 5.06).
# The current weather summary city num:361 for sena madureira is: (-9.07, -68.66, 75.56, 92, 8, 2.04).
# The current weather summary city num:362 for jeremoabo is: (-10.08, -38.34, 71.06, 80, 0, 10.98).
# The current weather summary city num:363 for barcelos is: (41.53, -8.62, 56.43, 42, 0, 2.04).
# The current weather summary city num:364 for amga is: (60.89, 131.98, 42.35, 79, 92, 3.6).
# The current weather summary city num:365 for ilhabela is: (-23.78, -45.36, 72.5, 100, 68, 7.07).
# The current weather summary city num:366 for boffa is: (10.18, -14.04, 73.4, 99, 88, 1.48).
# The current weather summary city num:367 for birjand is: (32.86, 59.22, 51.8, 34, 0, 6.93).
# The current weather summary city num:368 for oum hadjer is: (13.3, 19.7, 77.27, 71, 8, 8.75).
# Current city object for ye: not found.
# The current weather summary city num:369 for touros is: (-5.2, -35.46, 75.83, 95, 100, 11.99).
# The current weather summary city num:370 for alice springs is: (-23.7, 133.88, 73.4, 38, 0, 13.87).
# The current weather summary city num:371 for talnakh is: (69.49, 88.39, 30.74, 94, 80, 18.48).
# The current weather summary city num:372 for chimoio is: (-19.11, 33.48, 63.77, 97, 76, 6.62).
# The current weather summary city num:373 for rantepao is: (-2.97, 119.9, 79.34, 74, 24, 3.38).
# The current weather summary city num:374 for beloha is: (-25.17, 45.06, 58.73, 91, 36, 3.38).
# The current weather summary city num:375 for asyut is: (27.18, 31.19, 77, 53, 0, 9.17).
# The current weather summary city num:376 for itarema is: (-2.92, -39.92, 75.56, 88, 8, 11.77).
# The current weather summary city num:377 for belmonte is: (40.36, -7.35, 49.73, 71, 0, 5.17).
# The current weather summary city num:378 for rio negrinho is: (-26.26, -49.52, 57.74, 100, 88, 7.07).
# The current weather summary city num:379 for saint-pierre is: (48.95, 4.24, 44.44, 93, 0, 4.7).
# The current weather summary city num:380 for bom jesus is: (-5.99, -35.58, 80.6, 74, 75, 12.75).
# The current weather summary city num:381 for kloulklubed is: (7.04, 134.26, 87.8, 66, 75, 8.05).
# The current weather summary city num:382 for mount isa is: (-20.73, 139.49, 86, 25, 0, 11.41).
# The current weather summary city num:383 for broome is: (52.47, 1.45, 51.28, 93, 0, 8.05).
# The current weather summary city num:384 for paragominas is: (-3, -47.35, 76.91, 88, 48, 4.16).
# The current weather summary city num:385 for beysehir is: (37.68, 31.72, 47.48, 100, 8, 2.82).
# The current weather summary city num:386 for shelburne is: (44.08, -80.2, 59, 87, 90, 14.99).
# The current weather summary city num:387 for kalabo is: (-15, 22.67, 59.99, 31, 0, 7.52).
# The current weather summary city num:388 for kamenka is: (53.19, 44.05, 45.32, 93, 88, 14.79).
# The current weather summary city num:389 for ancud is: (-41.87, -73.83, 41, 87, 12, 5.17).
# The current weather summary city num:390 for shahpur is: (22.19, 77.91, 81.41, 71, 8, 4.27).
# The current weather summary city num:391 for berlevag is: (70.86, 29.09, 36.59, 100, 88, 15.57).
# The current weather summary city num:392 for cranbrook is: (49.51, -115.76, 34.12, 86, 75, 3.36).
# The current weather summary city num:393 for sarakhs is: (36.54, 61.16, 60.8, 51, 0, 6.93).
# The current weather summary city num:394 for schuttorf is: (52.32, 7.23, 50, 81, 75, 4.7).
# The current weather summary city num:395 for tucupita is: (9.06, -62.05, 80.6, 81, 8, 8.52).
# The current weather summary city num:396 for avera is: (33.19, -82.53, 76.23, 86, 90, 5.61).
# The current weather summary city num:397 for west wendover is: (40.74, -114.07, 62.06, 64, 40, 4.7).
# The current weather summary city num:398 for shimoda is: (34.7, 138.93, 71.6, 78, 75, 19.46).
# The current weather summary city num:399 for nemyriv is: (50.1, 23.44, 44.6, 87, 75, 11.18).
# The current weather summary city num:400 for fairlie is: (33.31, -95.96, 78.6, 70, 1, 6.93).
# The current weather summary city num:401 for karakol is: (42.49, 78.39, 44.96, 48, 0, 2.48).
# The current weather summary city num:402 for mendi is: (9.8, 35.1, 55.13, 92, 48, 2.71).
# The current weather summary city num:403 for mitsamiouli is: (-11.38, 43.28, 75.2, 100, 0, 3.94).
# The current weather summary city num:404 for zhaoyuan is: (45.52, 125.08, 69.98, 56, 0, 11.43).
# The current weather summary city num:405 for toora-khem is: (52.47, 96.11, 32, 72, 76, 4.27).
# The current weather summary city num:406 for anloga is: (5.79, 0.9, 78.8, 88, 40, 5.82).
# The current weather summary city num:407 for torbat-e jam is: (35.24, 60.63, 48.2, 76, 0, 4.16).
# The current weather summary city num:408 for haukipudas is: (65.17, 25.5, 24.8, 85, 0, 2.24).
# The current weather summary city num:409 for luang prabang is: (19.89, 102.14, 75.2, 78, 20, 2.24).
# The current weather summary city num:410 for huntsville is: (34.73, -86.59, 74.52, 78, 1, 4.7).
# The current weather summary city num:411 for pontianak is: (-0.02, 109.34, 82.4, 83, 20, 5.82).
# The current weather summary city num:412 for vestmannaeyjar is: (63.44, -20.27, 41.54, 100, 92, 17.13).
# The current weather summary city num:413 for vikulovo is: (55.07, 40.96, 43.16, 92, 88, 15.46).
# The current weather summary city num:414 for lagoa is: (37.14, -8.45, 69.8, 73, 0, 6.93).
# The current weather summary city num:415 for jishou is: (28.26, 109.7, 73.31, 70, 0, 3.94).
# The current weather summary city num:416 for inongo is: (-1.93, 18.29, 70.43, 100, 92, 2.71).
# The current weather summary city num:417 for pisco is: (-13.71, -76.2, 64.4, 82, 0, 9.17).
# The current weather summary city num:418 for iquitos is: (-3.75, -73.25, 75.2, 94, 40, 3.36).
# Current city object for meyungs: not found.
# The current weather summary city num:419 for husavik is: (50.56, -96.99, 35.06, 99, 0, 14.23).
# The current weather summary city num:420 for guhagar is: (17.48, 73.19, 79.97, 100, 36, 4.38).
# The current weather summary city num:421 for tulu bolo is: (8.66, 38.21, 46.49, 86, 0, 4.16).
# The current weather summary city num:422 for vung tau is: (10.35, 107.08, 80.6, 94, 40, 3.36).
# Current city object for marcona: not found.
# The current weather summary city num:423 for bud is: (62.91, 6.91, 42.85, 93, 92, 8.05).
# The current weather summary city num:424 for kysyl-syr is: (63.9, 122.77, 40.1, 74, 44, 7.07).
# The current weather summary city num:425 for beyneu is: (45.32, 55.19, 58.28, 47, 56, 6.73).
# The current weather summary city num:426 for caxito is: (-22.65, -42.51, 75.2, 83, 75, 3.36).
# The current weather summary city num:427 for poum is: (41.28, 20.71, 44.51, 95, 32, 1.7).
# The current weather summary city num:428 for constitucion is: (23.99, -104.67, 73.4, 40, 5, 4.7).
# The current weather summary city num:429 for ourossogui is: (15.61, -13.32, 79.16, 70, 0, 2.71).
# The current weather summary city num:430 for rapid valley is: (44.06, -103.15, 39.79, 13, 1, 14.99).
# The current weather summary city num:431 for swan hill is: (-35.34, 143.56, 64.13, 57, 0, 17.69).
# The current weather summary city num:432 for rundu is: (-17.91, 19.77, 57.38, 25, 0, 5.39).
# Current city object for nizhniy tagil-39: not found.
# The current weather summary city num:433 for vila franca do campo is: (37.72, -25.43, 69.8, 83, 40, 6.93).
# The current weather summary city num:434 for hue is: (16.47, 107.58, 84.2, 74, 40, 10.29).
# The current weather summary city num:435 for islamkot is: (24.7, 70.18, 73.76, 90, 8, 4.61).
# Current city object for artyk: not found.
# The current weather summary city num:436 for naze is: (5.43, 7.07, 73.31, 99, 76, 2.93).
# The current weather summary city num:437 for el dorado is: (6.71, -61.64, 70.88, 99, 56, 1.92).
# The current weather summary city num:438 for bati is: (11.19, 40.02, 59.9, 72, 0, 3.15).
# The current weather summary city num:439 for japura is: (-0.42, 102.29, 82.58, 85, 24, 2.93).
# The current weather summary city num:440 for jasper is: (33.83, -87.28, 74.93, 100, 1, 4.16).
# Current city object for jhikargachha: not found.
# The current weather summary city num:441 for kaliua is: (-5.06, 31.79, 67.1, 90, 92, 5.39).
# The current weather summary city num:442 for tazovskiy is: (67.47, 78.7, 41, 96, 92, 11.21).
# The current weather summary city num:443 for triunfo is: (-7.84, -38.1, 82.49, 37, 88, 0.92).
# The current weather summary city num:444 for sinazongwe is: (-17.26, 27.46, 64.58, 75, 0, 3.15).
# The current weather summary city num:445 for alexandria is: (31.31, -92.44, 77.9, 90, 40, 6.06).
# The current weather summary city num:446 for uige is: (-7.61, 15.06, 66.2, 97, 76, 2.59).
# The current weather summary city num:447 for magadan is: (59.56, 150.8, 50, 100, 32, 11.18).
# The current weather summary city num:448 for vila is: (45.18, 8.4, 50.02, 93, 0, 5.82).
# The current weather summary city num:449 for presidencia roque saenz pena is: (-26.79, -60.44, 62.33, 73, 68, 8.63).
# The current weather summary city num:450 for manoel urbano is: (-8.84, -69.26, 77.27, 86, 12, 2.15).
# The current weather summary city num:451 for persianovskiy is: (47.51, 40.11, 52.43, 79, 64, 7.52).
# The current weather summary city num:452 for biak is: (-0.91, 122.88, 77, 100, 92, 3.94).
# The current weather summary city num:453 for moerai is: (-22.43, -151.33, 70.88, 100, 56, 16.91).
# The current weather summary city num:454 for cam ranh is: (11.92, 109.15, 76.64, 100, 92, 9.08).
# Current city object for warqla: not found.
# The current weather summary city num:455 for magdagachi is: (53.45, 125.8, 59.9, 51, 0, 4.83).
# The current weather summary city num:456 for karratha is: (-20.74, 116.85, 98.15, 17, 12, 7.29).
# The current weather summary city num:457 for muli is: (22.62, 71.45, 78.44, 64, 0, 4.61).
# The current weather summary city num:458 for marovoay is: (-16.11, 46.64, 73.4, 88, 0, 8.08).
# The current weather summary city num:459 for kuminskiy is: (58.67, 66.57, 46.04, 78, 92, 4.72).
# The current weather summary city num:460 for le port is: (42.87, 1.37, 27.14, 87, 0, 1.36).
# The current weather summary city num:461 for brae is: (60.4, -1.35, 52.81, 100, 92, 14.99).
# The current weather summary city num:462 for havre-saint-pierre is: (50.23, -63.6, 46.4, 93, 90, 13.87).
# The current weather summary city num:463 for qasigiannguit is: (68.82, -51.19, 23, 73, 80, 4.61).
# The current weather summary city num:464 for las vegas is: (36.17, -115.15, 81.45, 26, 40, 10.29).
# The current weather summary city num:465 for eloy is: (32.76, -111.56, 83.19, 58, 1, 2.71).
# The current weather summary city num:466 for tankhoy is: (51.55, 105.12, 34.25, 100, 92, 21.72).
# The current weather summary city num:467 for saint-augustin is: (44.83, -0.61, 51.64, 87, 0, 2.24).
# The current weather summary city num:468 for padang is: (-0.92, 100.36, 81.32, 100, 20, 1.36).
# Current city object for maykain: not found.
# The current weather summary city num:469 for grenaa is: (56.42, 10.88, 42.8, 93, 44, 4.7).
# The current weather summary city num:470 for mayor pablo lagerenza is: (-19.93, -60.77, 66.65, 76, 64, 10.98).
# The current weather summary city num:471 for nouadhibou is: (20.93, -17.03, 78.8, 57, 68, 13.87).
# The current weather summary city num:472 for ust-ilimsk is: (57.96, 102.73, 39.38, 66, 0, 4.38).
# The current weather summary city num:473 for kezmarok is: (49.14, 20.43, 37.4, 69, 20, 4.7).
# The current weather summary city num:474 for sao gabriel is: (-30.34, -54.32, 46.85, 88, 12, 2.71).
# The current weather summary city num:475 for chillicothe is: (39.33, -82.98, 73.04, 84, 1, 9.17).
# The current weather summary city num:476 for lakes entrance is: (-37.88, 147.99, 54.59, 100, 80, 8.75).
# The current weather summary city num:477 for balkanabat is: (39.51, 54.36, 57.11, 76, 0, 2.04).
# The current weather summary city num:478 for alofi is: (-19.06, -169.92, 80.6, 69, 75, 14.99).
# Current city object for yirol: not found.
# The current weather summary city num:479 for serebryansk is: (49.68, 83.3, 28.4, 100, 90, 2.71).
# The current weather summary city num:480 for moussoro is: (13.64, 16.49, 73.76, 76, 0, 2.93).
# Current city object for paradwip: not found.
# The current weather summary city num:481 for sechura is: (-5.56, -80.82, 67.73, 87, 80, 10.76).
# The current weather summary city num:482 for the valley is: (18.22, -63.06, 82.4, 74, 20, 2.24).
# Current city object for karaul: not found.
# The current weather summary city num:483 for visnes is: (59.36, 5.22, 45.39, 87, 92, 12.75).
# The current weather summary city num:484 for huarmey is: (-10.07, -78.15, 61.16, 81, 88, 2.93).
# The current weather summary city num:485 for kolyvan is: (55.31, 82.74, 39.2, 80, 40, 8.95).
# The current weather summary city num:486 for riviere-au-renard is: (49, -64.4, 48.2, 93, 90, 6.93).
# The current weather summary city num:487 for tanout is: (14.97, 8.88, 77.63, 56, 56, 2.26).
# The current weather summary city num:488 for antsohihy is: (-14.88, 47.99, 66.47, 92, 0, 3.49).
# The current weather summary city num:489 for ankpa is: (7.37, 7.63, 74.03, 96, 48, 6.62).
# The current weather summary city num:490 for lubumbashi is: (-11.66, 27.48, 65.66, 53, 44, 9.64).
# The current weather summary city num:491 for colares is: (38.8, -9.45, 61.74, 28, 0, 3.36).
# The current weather summary city num:492 for evans is: (40.38, -104.69, 64.94, 49, 75, 17.22).
# The current weather summary city num:493 for sola is: (58.89, 5.65, 45.61, 81, 75, 8.05).
# The current weather summary city num:494 for oranjemund is: (-28.55, 16.43, 63.5, 74, 0, 16.35).
# The current weather summary city num:495 for lasa is: (34.92, 32.53, 66.2, 77, 0, 8.05).
# The current weather summary city num:496 for guerrero negro is: (27.97, -114.04, 67.91, 88, 0, 6.96).
# The current weather summary city num:497 for nha trang is: (12.24, 109.19, 76.64, 100, 92, 9.08).
# The current weather summary city num:498 for antigonish is: (45.62, -61.99, 59, 93, 90, 12.75).
# The current weather summary city num:499 for emerald is: (-23.53, 148.16, 83.57, 35, 32, 5.73).
# The current weather summary city num:500 for newport is: (51.59, -3, 54.86, 100, 90, 8.05).
# The current weather summary city num:501 for rognan is: (67.1, 15.4, 39.2, 86, 75, 5.82).
# The current weather summary city num:502 for kwinana is: (-32.25, 115.77, 66.25, 82, 40, 13.87).
# The current weather summary city num:503 for mokolo is: (10.74, 13.8, 66.56, 85, 0, 2.59).
# The current weather summary city num:504 for anaconda is: (46.13, -112.94, 51.08, 8, 1, 12.75).
# The current weather summary city num:505 for flic en flac is: (-20.27, 57.36, 60.8, 82, 20, 9.17).
# The current weather summary city num:506 for shalya is: (57.25, 58.73, 45.77, 78, 88, 6.73).
# The current weather summary city num:507 for moundsville is: (39.92, -80.74, 70.3, 92, 1, 3.36).
# Current city object for stornoway: not found.
# The current weather summary city num:508 for lambarene is: (-0.7, 10.22, 74.48, 96, 48, 2.04).
# The current weather summary city num:509 for oriximina is: (-1.77, -55.87, 85.01, 54, 0, 5.39).
# The current weather summary city num:510 for namibe is: (-15.19, 12.15, 66.47, 99, 0, 3.83).
# The current weather summary city num:511 for magway is: (20.15, 94.92, 80.42, 91, 32, 4.72).
# The current weather summary city num:512 for nagato is: (34.35, 131.14, 69.73, 60, 75, 8.05).
# The current weather summary city num:513 for tabuk is: (17.41, 121.44, 78.53, 66, 8, 1.7).
# The current weather summary city num:514 for aguada de pasajeros is: (22.38, -80.85, 77, 83, 0, 9.17).
# The current weather summary city num:515 for haines junction is: (60.75, -137.51, 31.37, 77, 20, 1.92).
# Current city object for krasnousolskiy: not found.
# The current weather summary city num:516 for mandalgovi is: (45.76, 106.27, 46.85, 62, 0, 20.49).
# The current weather summary city num:517 for shalinskoye is: (55.72, 93.76, 40.01, 85, 88, 6.96).
# The current weather summary city num:518 for riyadh is: (24.63, 46.72, 73.4, 20, 0, 2.71).
# The current weather summary city num:519 for ulagan is: (50.63, 87.96, 23.18, 67, 0, 2.82).
# The current weather summary city num:520 for ucluelet is: (48.94, -125.55, 51.8, 66, 75, 6.93).
# The current weather summary city num:521 for paramonga is: (-10.68, -77.82, 60.89, 100, 68, 5.28).
# The current weather summary city num:522 for hinton is: (53.4, -117.57, 26.33, 66, 32, 2.26).
# The current weather summary city num:523 for maple creek is: (49.91, -109.46, 14.45, 66, 24, 2.71).
# The current weather summary city num:524 for jaguaruna is: (-28.62, -49.03, 64.04, 100, 100, 3.15).
# The current weather summary city num:525 for preobrazheniye is: (42.9, 133.91, 65.3, 49, 0, 2.59).
# The current weather summary city num:526 for jicin is: (50.44, 15.35, 47.61, 76, 0, 4.7).
# The current weather summary city num:527 for severodvinsk is: (64.56, 39.82, 37.4, 100, 90, 2.24).
# The current weather summary city num:528 for sulangan is: (11.14, 123.72, 83.21, 100, 56, 6.85).
# The current weather summary city num:529 for makueni is: (-1.8, 37.62, 62.78, 97, 92, 5.73).
# Current city object for rawannawi: not found.
# Current city object for wulanhaote: not found.
# The current weather summary city num:530 for ginir is: (7.14, 40.71, 55.13, 85, 12, 2.71).
# Current city object for novoyegoryevskoye: not found.
# The current weather summary city num:531 for hambantota is: (6.12, 81.12, 78.08, 100, 92, 5.95).
# The current weather summary city num:532 for nizhniy baskunchak is: (48.22, 46.83, 57.92, 92, 36, 11.43).
# The current weather summary city num:533 for lanigan is: (51.85, -105.03, 31.1, 74, 36, 8.41).
# The current weather summary city num:534 for jabinyanah is: (35.03, 10.91, 62.6, 67, 20, 4.7).
# The current weather summary city num:535 for fuling is: (29.71, 107.39, 65.21, 88, 48, 3.83).
# The current weather summary city num:536 for dunmore town is: (25.5, -76.65, 82.13, 100, 88, 23.4).
# The current weather summary city num:537 for laguna is: (27.52, -110.01, 87.8, 52, 5, 3.94).
# The current weather summary city num:538 for puerto ayacucho is: (5.66, -67.63, 82.4, 78, 40, 2.71).
# Current city object for huazolotitlan: not found.
# The current weather summary city num:539 for tambo is: (-24.88, 146.25, 82.76, 31, 36, 11.43).
# The current weather summary city num:540 for fili is: (8.43, 4.5, 73.04, 95, 68, 4.16).
# The current weather summary city num:541 for isla mujeres is: (21.23, -86.73, 80.6, 83, 20, 8.05).
# The current weather summary city num:542 for mildura is: (-34.18, 142.16, 65.21, 51, 0, 19.04).
# The current weather summary city num:543 for kaniama is: (-7.57, 24.18, 68.36, 89, 32, 2.59).
# The current weather summary city num:544 for tiznit is: (29.7, -9.73, 66.29, 95, 44, 1.48).
# The current weather summary city num:545 for kainan is: (34.15, 135.21, 68, 82, 75, 5.82).
# The current weather summary city num:546 for cartagena del chaira is: (1.33, -74.84, 74.84, 95, 8, 2.04).

# %%
#print(weather_data)
print(len(weather_data))
# Out:
# 546

# %%
column_names = ["Latitude", "Longitude", "Temperature(F)", "Humidity%", "Clouds%", "Wind Speed(mph)"]
weather = pd.DataFrame(weather_data, index=cities, columns=column_names)
weather.head()
# Out:
#         Latitude  Longitude  Temperature(F)  Humidity%  Clouds%  \
# faanui    -16.48    -151.75           78.17        100       64
# albany     42.65     -73.75           56.23         89       40
# castro    -42.48     -73.76           40.10        100        0
# palmer    -34.85     139.16           59.00         44       75
# vaini      15.34      74.49           75.11         89        0
#
#         Wind Speed(mph)
# faanui            21.83
# albany             2.15
# castro             5.39
# palmer            13.87
# vaini              4.27

# %%
weather.to_csv("WeatherPy_Output/WorldWeatherData.csv", index=False)

# %%
# %matplotlib notebook
x_values = weather["Latitude"]
y_temp_values = weather["Temperature(F)"]
plt.scatter(x_values,y_temp_values, c = y_temp_values, edgecolor="black", linewidths=1, marker="o", 
            cmap='plasma',alpha=0.8, label="City")

# Incorporate the other graph properties
plt.style.use('seaborn')
plt.title(f"City Latitude vs. Max Temperature {time.strftime('%m/%d/%Y')}")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-70, 90])
plt.ylim([-10, 110])

# Save the figure
plt.savefig("WeatherPy_Output/Latitude_Temperature.png")
#plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# %matplotlib notebook
x_values = weather["Latitude"]
y_humidity_values = weather["Humidity%"]
plt.scatter(x_values,y_humidity_values, c= y_humidity_values, edgecolor="black", linewidths=1, marker="o", 
            cmap='GnBu',alpha=0.8, label="City")


plt.style.use('seaborn')
plt.title(f"City Latitude vs. Humidity % {time.strftime('%m/%d/%Y')}")
plt.ylabel("Humidity %")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-80, 100])
plt.ylim([-5, 125])
plt.savefig("WeatherPy_Output/Latitude_Humidity.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# %matplotlib notebook
x_values = weather["Longitude"]
y_humidity_values = weather["Humidity%"]
plt.scatter(x_values,y_humidity_values, c= y_humidity_values, edgecolor="black", linewidths=1, marker="o", 
            cmap='winter',alpha=0.8, label="City")
plt.style.use('seaborn')
plt.title(f"City Longitude vs. Humidity% {time.strftime('%m/%d/%Y')}")
plt.ylabel("Humidity %")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-180, 180])
plt.ylim([0, 110])
plt.savefig("WeatherPy_Output/Longitude_Humidity.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# %matplotlib notebook
x_values = weather["Latitude"]
y_clouds_values = weather["Clouds%"]
plt.scatter(x_values,y_clouds_values, c= y_clouds_values, edgecolor="black", linewidths=1, marker="o", 
            cmap='autumn',alpha=0.8, label="City")
plt.style.use('seaborn')
plt.title(f"City Latitude vs. Clouds % {time.strftime('%m/%d/%Y')}")
plt.ylabel("Clouds %")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-70, 90])
plt.ylim([-5, 105])
plt.savefig("WeatherPy_Output/Latitude_Clouds.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# %matplotlib notebook
x_values = weather["Latitude"]
y_wind_values = weather["Wind Speed(mph)"]
plt.scatter(x_values,y_wind_values, c= y_wind_values, edgecolor="black", linewidths=1, marker="o", 
            cmap='gist_earth',alpha=0.8, label="City")
plt.style.use('seaborn')
plt.title(f"City Latitude vs. Wind Speed(mph) {time.strftime('%m/%d/%Y')}")
plt.ylabel("Wind Speed(mph)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-70, 90])
plt.ylim([-1, 30])
plt.savefig("WeatherPy_Output/Latitude_WindSpeed.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# As a short analysis:
# **Temparature tends to get higher when the latitude gets cloder to 0.
# **Humidity does not have a pattern with latitude, but it seems that the humidity doesn't get lower than 40% around latitude 0.
# **Cloud percent has an interesting plot. It doesn't seem completly scattered, rather cloud values seem to be collected around certain percentages but distributed along many different latitude values. (It looks like a few clouds percent is equal to some value no matter what latitude line is drawn.)(a few different y=a lines)
