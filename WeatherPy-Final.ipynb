# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import API key

import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy
# Dependencies
import openweathermapy as owm

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
first_cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1550)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1550)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in first_cities:
        first_cities.append(city)

# Print the city count to confirm sufficient count
len(first_cities)
# Out:
# 631

# %% [markdown]
# ## Perform API Calls

# %%
# OpenWeatherMap API Key
api_key = api_keys.api_key

# Create settings dictionary with information we're interested in
settings = {"units": "imperial", "appid": api_key}

# Get current weather
weather_data = []
num = 0
cities = []
for city in first_cities:
    try:
        current_weather_city = owm.get_current(city, **settings)
        #print(f"Current weather object for {city}: {current_weather_city}.")
        summary = ["coord.lat", "coord.lon", "main.temp", "main.humidity", "clouds.all", "wind.speed"]
        data = current_weather_city(*summary)
        cities.append(city)
        num += 1
        print(f"The current weather summary city num:{num} for {city} is: {data}.")
        weather_data.append(data)
        #print(weather_data)
        
    except:
        print(f"Current city object for {city}: not found.")
        first_cities.remove(city)
        
#print(num)
#print(len(cities))
#print(len(first_cities))
# Out:
# The current weather summary city num:1 for russell is: (-33.01, -68.8, 60.8, 44, 0, 3.36).
# The current weather summary city num:2 for east london is: (-33.02, 27.91, 60.53, 100, 88, 9.75).
# The current weather summary city num:3 for shakawe is: (-18.36, 21.84, 56.3, 37, 0, 2.71).
# The current weather summary city num:4 for cabo san lucas is: (22.89, -109.91, 81.59, 74, 5, 6.93).
# The current weather summary city num:5 for lompoc is: (34.64, -120.46, 66.31, 89, 90, 3.36).
# The current weather summary city num:6 for maniitsoq is: (65.42, -52.9, 31.46, 100, 88, 5.28).
# The current weather summary city num:7 for bredasdorp is: (-34.53, 20.04, 44.6, 87, 0, 5.82).
# The current weather summary city num:8 for hilo is: (19.71, -155.08, 75.42, 69, 40, 11.41).
# The current weather summary city num:9 for doha is: (25.29, 51.53, 86, 74, 0, 5.82).
# Current city object for kazalinsk: not found.
# The current weather summary city num:10 for ormara is: (25.21, 64.64, 78.62, 80, 0, 5.95).
# The current weather summary city num:11 for port alfred is: (-33.59, 26.89, 59.54, 100, 64, 6.85).
# The current weather summary city num:12 for yellowknife is: (62.45, -114.38, 24.8, 62, 90, 3.36).
# The current weather summary city num:13 for qaanaaq is: (77.48, -69.36, 16.34, 100, 0, 15.57).
# The current weather summary city num:14 for praia da vitoria is: (38.73, -27.07, 68, 94, 20, 9.08).
# The current weather summary city num:15 for ploemeur is: (47.73, -3.43, 50.79, 100, 0, 6.93).
# The current weather summary city num:16 for atuona is: (-9.8, -139.03, 79.34, 100, 0, 14.45).
# The current weather summary city num:17 for vaini is: (15.34, 74.49, 75.11, 89, 0, 4.27).
# The current weather summary city num:18 for cockburn town is: (21.46, -71.14, 82.4, 100, 64, 9.42).
# The current weather summary city num:19 for walvis bay is: (-22.95, 14.51, 57.2, 82, 0, 8.05).
# The current weather summary city num:20 for saint-augustin is: (44.83, -0.61, 51.62, 87, 0, 3.36).
# The current weather summary city num:21 for tigzirt is: (36.57, 4.2, 55.67, 100, 92, 1.92).
# The current weather summary city num:22 for butaritari is: (3.07, 172.79, 85.1, 100, 8, 6.4).
# The current weather summary city num:23 for zarubino is: (42.65, 131.06, 67.37, 85, 0, 4.27).
# The current weather summary city num:24 for mataura is: (-46.19, 168.86, 45.14, 100, 80, 7.18).
# The current weather summary city num:25 for busselton is: (-33.64, 115.35, 68.27, 82, 76, 16.02).
# The current weather summary city num:26 for cidreira is: (-30.17, -50.22, 54.86, 92, 24, 4.61).
# The current weather summary city num:27 for new norfolk is: (-42.78, 147.06, 53.6, 46, 20, 10.29).
# The current weather summary city num:28 for ambovombe is: (-25.18, 46.09, 63.86, 100, 0, 6.4).
# The current weather summary city num:29 for anadyr is: (64.73, 177.51, 50, 87, 90, 17.9).
# Current city object for belushya guba: not found.
# The current weather summary city num:30 for barrow is: (-38.31, -60.23, 43.43, 68, 0, 5.61).
# The current weather summary city num:31 for isnos is: (1.94, -76.24, 52.88, 94, 20, 1.7).
# The current weather summary city num:32 for xai-xai is: (-25.04, 33.64, 65.84, 100, 100, 27.42).
# The current weather summary city num:33 for hasaki is: (35.73, 140.83, 72.21, 68, 75, 14.99).
# The current weather summary city num:34 for byron bay is: (-28.65, 153.62, 73.4, 60, 32, 19.46).
# Current city object for tsihombe: not found.
# Current city object for taolanaro: not found.
# The current weather summary city num:35 for rikitea is: (-23.12, -134.97, 68.81, 100, 36, 19.26).
# The current weather summary city num:36 for berlevag is: (70.86, 29.09, 36.59, 100, 88, 15.57).
# Current city object for bengkulu: not found.
# The current weather summary city num:37 for victoria is: (5.28, 115.24, 86.92, 79, 75, 4.7).
# The current weather summary city num:38 for provideniya is: (64.42, -173.23, 50, 81, 90, 8.95).
# The current weather summary city num:39 for husavik is: (50.56, -96.99, 35.06, 99, 0, 14.23).
# The current weather summary city num:40 for fortuna is: (38.18, -1.13, 61.7, 77, 0, 2.24).
# The current weather summary city num:41 for vostok is: (46.45, 135.83, 60.8, 49, 0, 2.82).
# The current weather summary city num:42 for mar del plata is: (-46.43, -67.52, 49.91, 50, 32, 7.63).
# The current weather summary city num:43 for saint-philippe is: (45.36, -73.48, 51.66, 93, 90, 6.93).
# The current weather summary city num:44 for souillac is: (45.6, -0.6, 51.8, 87, 0, 7.63).
# The current weather summary city num:45 for hami is: (42.84, 93.51, 56.21, 43, 0, 5.73).
# The current weather summary city num:46 for jardim is: (-21.48, -56.15, 71.33, 92, 44, 4.5).
# The current weather summary city num:47 for lebu is: (8.96, 38.73, 53.6, 71, 20, 2.24).
# The current weather summary city num:48 for port-gentil is: (-0.72, 8.78, 76.55, 99, 64, 6.17).
# The current weather summary city num:49 for mareeba is: (-16.99, 145.42, 82.4, 51, 20, 14.99).
# The current weather summary city num:50 for waingapu is: (-9.65, 120.26, 88.34, 51, 0, 8.41).
# The current weather summary city num:51 for hithadhoo is: (-0.6, 73.08, 83.03, 100, 80, 23.06).
# The current weather summary city num:52 for bratsk is: (56.15, 101.63, 33.8, 69, 36, 4.47).
# The current weather summary city num:53 for opole is: (50.67, 17.92, 44.51, 81, 8, 11.88).
# Current city object for barentsburg: not found.
# The current weather summary city num:54 for solginskiy is: (61.05, 41.34, 43.7, 99, 92, 10.65).
# The current weather summary city num:55 for caucaia is: (-3.73, -38.66, 78.8, 78, 20, 10.29).
# Current city object for olafsvik: not found.
# The current weather summary city num:56 for fuerte olimpo is: (-21.04, -57.87, 72.32, 80, 0, 9.53).
# The current weather summary city num:57 for jiwani is: (25.05, 61.74, 76.46, 99, 36, 3.15).
# Current city object for grand river south east: not found.
# Current city object for saleaula: not found.
# The current weather summary city num:58 for kavieng is: (-2.57, 150.8, 85.73, 100, 24, 4.38).
# The current weather summary city num:59 for bella union is: (8.5, -73.35, 65.84, 95, 36, 1.14).
# The current weather summary city num:60 for dikson is: (73.51, 80.55, 38.03, 100, 76, 19.04).
# The current weather summary city num:61 for thompson is: (55.74, -97.86, 28.4, 74, 40, 9.17).
# The current weather summary city num:62 for vestmannaeyjar is: (63.44, -20.27, 41.54, 100, 92, 17.13).
# The current weather summary city num:63 for asyut is: (27.18, 31.19, 68.81, 69, 0, 5.28).
# The current weather summary city num:64 for puerto ayora is: (-0.74, -90.35, 70.43, 100, 0, 12.1).
# The current weather summary city num:65 for yuxia is: (34.06, 108.63, 64.4, 52, 0, 6.71).
# The current weather summary city num:66 for ilulissat is: (69.22, -51.1, 23, 73, 80, 4.61).
# The current weather summary city num:67 for kindberg is: (47.51, 15.45, 42.8, 100, 20, 1.12).
# The current weather summary city num:68 for boundiali is: (9.53, -6.48, 71.78, 91, 20, 2.71).
# Current city object for banmo: not found.
# The current weather summary city num:69 for tasiilaq is: (65.61, -37.64, 30.2, 54, 56, 3.36).
# The current weather summary city num:70 for el angel is: (0.62, -77.93, 50.18, 100, 20, 2.15).
# The current weather summary city num:71 for khislavichi is: (54.19, 32.16, 43.61, 96, 92, 15.46).
# The current weather summary city num:72 for kahama is: (-3.83, 32.6, 65.84, 83, 56, 4.83).
# The current weather summary city num:73 for surt is: (31.21, 16.59, 73.49, 100, 12, 9.53).
# The current weather summary city num:74 for careiro da varzea is: (-3.2, -59.81, 81.46, 69, 0, 2.24).
# The current weather summary city num:75 for baglan is: (51.62, -3.81, 55.4, 93, 90, 8.05).
# The current weather summary city num:76 for tuktoyaktuk is: (69.44, -133.03, 24.8, 79, 75, 14.99).
# The current weather summary city num:77 for pisco is: (-13.71, -76.2, 64.4, 82, 0, 6.93).
# The current weather summary city num:78 for humaita is: (-24.93, -65.37, 62.13, 67, 0, 9.17).
# The current weather summary city num:79 for rio grande is: (-32.03, -52.1, 53.24, 100, 0, 4.5).
# The current weather summary city num:80 for san quintin is: (17.54, 120.52, 82.4, 69, 20, 2.24).
# Current city object for tidore: not found.
# Current city object for bolshegrivskoye: not found.
# The current weather summary city num:81 for kodiak is: (39.95, -94.76, 82.94, 65, 1, 12.75).
# The current weather summary city num:82 for barcelos is: (41.53, -8.62, 55.33, 51, 0, 3.36).
# The current weather summary city num:83 for filingue is: (14.35, 3.32, 76.82, 77, 8, 2.37).
# The current weather summary city num:84 for ust-maya is: (60.42, 134.54, 43.34, 83, 68, 3.71).
# The current weather summary city num:85 for richards bay is: (-28.77, 32.06, 57.83, 99, 100, 13.89).
# The current weather summary city num:86 for kaitangata is: (-46.28, 169.85, 46.04, 100, 92, 12.21).
# The current weather summary city num:87 for sitka is: (37.17, -99.65, 73.58, 82, 56, 5.5).
# Current city object for samusu: not found.
# The current weather summary city num:88 for tarauaca is: (-8.16, -70.77, 78.44, 77, 8, 4.72).
# The current weather summary city num:89 for kendari is: (-3.99, 122.52, 88.7, 59, 24, 5.73).
# The current weather summary city num:90 for kutum is: (14.2, 24.66, 73.31, 58, 48, 7.63).
# The current weather summary city num:91 for poya is: (-21.35, 165.16, 71.33, 98, 80, 15.12).
# Current city object for illoqqortoormiut: not found.
# The current weather summary city num:92 for bluff is: (-23.58, 149.07, 84.92, 30, 12, 5.39).
# The current weather summary city num:93 for khatanga is: (71.98, 102.47, 30.56, 94, 64, 11.99).
# The current weather summary city num:94 for leningradskiy is: (69.38, 178.42, 40.37, 87, 24, 11.32).
# The current weather summary city num:95 for ribeira grande is: (38.52, -28.7, 72.32, 99, 76, 10.76).
# The current weather summary city num:96 for punta arenas is: (-53.16, -70.91, 41, 75, 75, 14.99).
# Current city object for sao raimundo nonato: not found.
# The current weather summary city num:97 for kapaa is: (22.08, -159.32, 83.1, 74, 40, 13.87).
# The current weather summary city num:98 for morgan city is: (29.7, -91.21, 76.39, 100, 1, 5.73).
# The current weather summary city num:99 for gisborne is: (-38.66, 178.02, 62.33, 59, 92, 8.41).
# The current weather summary city num:100 for bandarbeyla is: (9.49, 50.81, 76.1, 98, 12, 4.94).
# The current weather summary city num:101 for isabela is: (10.2, 122.99, 84.2, 79, 24, 3.6).
# The current weather summary city num:102 for majene is: (-3.54, 118.97, 84.11, 93, 0, 8.63).
# The current weather summary city num:103 for wamba is: (2.14, 27.99, 64.58, 98, 12, 2.15).
# The current weather summary city num:104 for lorengau is: (-2.02, 147.27, 84.47, 100, 24, 2.59).
# The current weather summary city num:105 for vicam is: (27.64, -110.3, 86.09, 58, 5, 5.61).
# The current weather summary city num:106 for carnarvon is: (-30.97, 22.13, 37.13, 72, 0, 9.64).
# The current weather summary city num:107 for isangel is: (-19.55, 169.27, 73.31, 100, 76, 9.64).
# The current weather summary city num:108 for puerto escondido is: (15.86, -97.07, 82.4, 69, 40, 5.82).
# The current weather summary city num:109 for jamestown is: (-33.21, 138.6, 56.03, 80, 0, 13).
# The current weather summary city num:110 for santiago is: (-33.44, -70.65, 59, 28, 0, 2.24).
# The current weather summary city num:111 for katherine is: (-14.47, 132.26, 91.4, 36, 0, 8.05).
# The current weather summary city num:112 for valparaiso is: (41.47, -87.06, 80.47, 54, 1, 20.8).
# The current weather summary city num:113 for karratha is: (-20.74, 116.85, 98.15, 17, 12, 7.29).
# The current weather summary city num:114 for nikolskoye is: (59.7, 30.79, 42.8, 81, 75, 13.42).
# The current weather summary city num:115 for longyearbyen is: (78.22, 15.63, 32, 100, 75, 11.41).
# The current weather summary city num:116 for sovetskiy is: (56.76, 48.47, 51.53, 96, 92, 15.23).
# The current weather summary city num:117 for campobasso is: (41.56, 14.66, 53.6, 91, 56, 2.71).
# Current city object for nguiu: not found.
# The current weather summary city num:118 for sutton coldfield is: (52.56, -1.82, 54.34, 93, 0, 4.7).
# The current weather summary city num:119 for sao felix do xingu is: (-6.64, -51.99, 75.11, 93, 0, 1.92).
# The current weather summary city num:120 for novoanninskiy is: (50.53, 42.67, 47.66, 79, 64, 11.21).
# The current weather summary city num:121 for ginda is: (30.69, 78.49, 55.22, 82, 44, 2.04).
# The current weather summary city num:122 for prieska is: (-29.67, 22.74, 45.5, 44, 0, 10.76).
# The current weather summary city num:123 for talaya is: (55.79, 84.89, 44.6, 70, 80, 9.19).
# The current weather summary city num:124 for novopskov is: (49.54, 39.1, 49.91, 75, 92, 11.77).
# The current weather summary city num:125 for constitucion is: (23.99, -104.67, 69.8, 49, 5, 4.7).
# The current weather summary city num:126 for salalah is: (17.01, 54.1, 73.4, 64, 0, 3.36).
# The current weather summary city num:127 for narsaq is: (60.91, -46.05, 35.6, 55, 12, 5.82).
# The current weather summary city num:128 for roald is: (62.58, 6.12, 42.57, 75, 92, 8.05).
# Current city object for amderma: not found.
# The current weather summary city num:129 for pathein is: (16.78, 94.73, 80.96, 97, 44, 5.17).
# The current weather summary city num:130 for anta is: (-13.47, -72.15, 53.6, 46, 20, 2.24).
# The current weather summary city num:131 for tiksi is: (71.64, 128.87, 28.13, 96, 12, 4.83).
# The current weather summary city num:132 for katobu is: (-4.94, 122.53, 87.8, 72, 8, 5.61).
# The current weather summary city num:133 for rawson is: (-43.3, -65.11, 53.06, 42, 8, 7.63).
# The current weather summary city num:134 for iqaluit is: (63.75, -68.52, 32, 100, 90, 21.92).
# The current weather summary city num:135 for beloha is: (-25.17, 45.06, 58.73, 91, 36, 3.38).
# The current weather summary city num:136 for bud is: (62.91, 6.91, 42.24, 93, 92, 8.05).
# Current city object for tabiauea: not found.
# The current weather summary city num:137 for dubbo is: (-32.25, 148.6, 60.8, 93, 75, 8.05).
# The current weather summary city num:138 for chiredzi is: (-21.05, 31.67, 64.58, 82, 100, 13.22).
# The current weather summary city num:139 for labuan is: (5.28, 115.24, 86.92, 79, 75, 4.7).
# The current weather summary city num:140 for bambous virieux is: (-20.34, 57.76, 60.8, 82, 20, 8.05).
# The current weather summary city num:141 for ixtapa is: (20.71, -105.21, 84.2, 94, 40, 0.25).
# The current weather summary city num:142 for katsuura is: (33.93, 134.5, 66.2, 88, 75, 5.82).
# The current weather summary city num:143 for mehamn is: (71.03, 27.85, 36.95, 96, 88, 14.9).
# The current weather summary city num:144 for gat is: (14.69, -16.54, 77.81, 94, 0, 4.72).
# The current weather summary city num:145 for laguna is: (27.52, -110.01, 84.2, 58, 5, 3.94).
# The current weather summary city num:146 for alice town is: (25.72, -79.3, 81.77, 100, 48, 17.69).
# The current weather summary city num:147 for esperance is: (10.24, -61.45, 80.6, 94, 20, 5.82).
# The current weather summary city num:148 for haines junction is: (60.75, -137.51, 31.37, 77, 20, 1.92).
# The current weather summary city num:149 for los algarrobos is: (-3.25, -79.94, 89.6, 33, 90, 3.36).
# The current weather summary city num:150 for santa vitoria do palmar is: (-33.52, -53.37, 51.8, 89, 56, 5.17).
# The current weather summary city num:151 for kita is: (35.76, 139.74, 69.58, 68, 75, 8.05).
# The current weather summary city num:152 for luanda is: (-8.83, 13.24, 73.4, 88, 75, 4.7).
# The current weather summary city num:153 for harper is: (30.3, -99.24, 75.45, 71, 1, 3.36).
# The current weather summary city num:154 for barranca is: (-10.75, -77.76, 60.89, 100, 68, 5.28).
# The current weather summary city num:155 for mangrol is: (25.33, 76.51, 85.55, 48, 0, 2.15).
# The current weather summary city num:156 for komsomolskiy is: (67.55, 63.78, 40.28, 95, 92, 15.01).
# The current weather summary city num:157 for taltal is: (-25.41, -70.49, 55.31, 93, 76, 1.36).
# The current weather summary city num:158 for along is: (28.17, 94.8, 69.98, 72, 8, 1.81).
# The current weather summary city num:159 for bertoua is: (4.58, 13.68, 67.91, 95, 64, 5.17).
# The current weather summary city num:160 for santa is: (17.49, 120.43, 76.28, 83, 36, 2.15).
# The current weather summary city num:161 for inyonga is: (-6.72, 32.06, 73.04, 53, 68, 6.85).
# Current city object for lolua: not found.
# The current weather summary city num:162 for airai is: (-8.93, 125.41, 86.81, 42, 0, 1.14).
# Current city object for karauzyak: not found.
# Current city object for vaitupu: not found.
# The current weather summary city num:163 for georgetown is: (6.8, -58.16, 77, 94, 0, 6.93).
# The current weather summary city num:164 for port lincoln is: (-34.72, 135.86, 57.29, 91, 8, 13.78).
# The current weather summary city num:165 for lagunillas is: (8.5, -71.39, 66.2, 93, 75, 1.92).
# The current weather summary city num:166 for bayshore gardens is: (27.43, -82.59, 80.06, 76, 1, 5.82).
# The current weather summary city num:167 for pacific grove is: (36.62, -121.92, 64.56, 87, 75, 5.82).
# The current weather summary city num:168 for yenagoa is: (4.92, 6.26, 74.66, 98, 92, 3.38).
# The current weather summary city num:169 for swan river is: (52.11, -101.27, 31.46, 68, 24, 7.63).
# The current weather summary city num:170 for baiao is: (-2.79, -49.67, 77.27, 91, 20, 3.94).
# The current weather summary city num:171 for iacobeni is: (47.42, 25.31, 36.5, 89, 80, 5.06).
# The current weather summary city num:172 for mount pleasant is: (33.16, -94.97, 76.98, 83, 1, 4.7).
# The current weather summary city num:173 for caravelas is: (-17.73, -39.27, 77.36, 100, 36, 16.58).
# The current weather summary city num:174 for grand gaube is: (-20.01, 57.66, 60.8, 82, 20, 8.05).
# The current weather summary city num:175 for saskylakh is: (71.97, 114.09, 29.93, 92, 64, 12.44).
# The current weather summary city num:176 for parli is: (18.85, 76.53, 77.45, 75, 64, 1.36).
# The current weather summary city num:177 for pahalgam is: (34.03, 75.33, 30.47, 91, 80, 1.36).
# The current weather summary city num:178 for kahului is: (20.89, -156.47, 81.72, 65, 40, 20.8).
# The current weather summary city num:179 for kamenka is: (53.19, 44.05, 45.32, 93, 88, 14.79).
# The current weather summary city num:180 for coihaique is: (-45.58, -72.07, 41, 75, 0, 4.7).
# The current weather summary city num:181 for yangshe is: (31.89, 120.61, 77, 69, 12, 15.46).
# The current weather summary city num:182 for tucupita is: (9.06, -62.05, 80.6, 81, 8, 8.52).
# Current city object for meyungs: not found.
# Current city object for krasnoselkup: not found.
# The current weather summary city num:183 for lewisporte is: (49.25, -55.06, 46.4, 70, 90, 11.41).
# The current weather summary city num:184 for bay roberts is: (47.58, -53.28, 46.4, 75, 90, 10.29).
# The current weather summary city num:185 for baherden is: (38.44, 57.43, 61.7, 69, 24, 2.15).
# The current weather summary city num:186 for lavrentiya is: (65.58, -170.99, 47.03, 87, 92, 21.83).
# The current weather summary city num:187 for kozlovka is: (55.84, 48.25, 52.68, 93, 90, 13.42).
# The current weather summary city num:188 for flinders is: (-34.58, 150.85, 55.4, 100, 90, 11.41).
# The current weather summary city num:189 for marsh harbour is: (26.54, -77.06, 82.31, 100, 80, 21.72).
# The current weather summary city num:190 for torbay is: (47.66, -52.73, 46.4, 75, 90, 10.29).
# The current weather summary city num:191 for kharp is: (66.82, 65.8, 30.65, 92, 20, 7.4).
# The current weather summary city num:192 for malanje is: (-9.54, 16.35, 64.4, 99, 92, 3.6).
# The current weather summary city num:193 for ruteng is: (-8.61, 120.46, 84.56, 59, 20, 5.73).
# The current weather summary city num:194 for kadipaten is: (-6.76, 108.17, 85.01, 77, 8, 3.49).
# The current weather summary city num:195 for sao filipe is: (14.9, -24.5, 79.16, 95, 20, 13.33).
# The current weather summary city num:196 for yulara is: (-25.24, 130.99, 75.2, 36, 0, 14.99).
# The current weather summary city num:197 for mahebourg is: (-20.41, 57.7, 60.8, 82, 20, 8.05).
# The current weather summary city num:198 for paita is: (-5.09, -81.11, 67.28, 86, 88, 6.96).
# The current weather summary city num:199 for lagoa is: (37.14, -8.45, 69.8, 68, 0, 6.93).
# The current weather summary city num:200 for toora-khem is: (52.47, 96.11, 32, 72, 76, 4.27).
# The current weather summary city num:201 for kalabo is: (-15, 22.67, 59.99, 31, 0, 7.52).
# The current weather summary city num:202 for kavaratti is: (10.57, 72.64, 83.3, 100, 56, 11.21).
# The current weather summary city num:203 for mach is: (29.87, 67.33, 48.2, 41, 0, 1.59).
# The current weather summary city num:204 for rochester is: (44.02, -92.46, 57.78, 73, 75, 33.33).
# The current weather summary city num:205 for klaksvik is: (62.23, -6.59, 48.2, 93, 92, 12.75).
# The current weather summary city num:206 for port pirie is: (-33.18, 138.01, 59, 58, 90, 18.34).
# The current weather summary city num:207 for bilibino is: (68.06, 166.44, 37.13, 90, 68, 3.04).
# The current weather summary city num:208 for jalu is: (29.03, 21.55, 81.41, 29, 36, 10.76).
# The current weather summary city num:209 for alofi is: (-19.06, -169.92, 78.8, 69, 92, 14.99).
# The current weather summary city num:210 for coquimbo is: (-29.95, -71.34, 53.6, 87, 0, 2.24).
# The current weather summary city num:211 for nagar karnul is: (16.48, 78.32, 80.78, 70, 20, 4.05).
# The current weather summary city num:212 for marawi is: (8, 124.29, 81.95, 67, 24, 3.04).
# The current weather summary city num:213 for sibolga is: (1.74, 98.78, 74.3, 97, 76, 1.14).
# The current weather summary city num:214 for kalmunai is: (7.42, 81.82, 78.44, 96, 64, 4.94).
# The current weather summary city num:215 for hualmay is: (-11.1, -77.61, 59.18, 94, 24, 3.04).
# The current weather summary city num:216 for cajnice is: (43.56, 19.07, 39.74, 93, 0, 0.92).
# The current weather summary city num:217 for polson is: (47.69, -114.16, 37.4, 72, 64, 1.92).
# The current weather summary city num:218 for paamiut is: (61.99, -49.67, 35.6, 100, 12, 4.5).
# The current weather summary city num:219 for nyurba is: (63.29, 118.35, 41.36, 64, 76, 7.96).
# The current weather summary city num:220 for cherskiy is: (68.75, 161.3, 36.05, 88, 88, 7.18).
# The current weather summary city num:221 for la ronge is: (55.1, -105.3, 28.4, 63, 40, 11.41).
# The current weather summary city num:222 for itarema is: (-2.92, -39.92, 75.56, 88, 8, 11.77).
# The current weather summary city num:223 for nouakchott is: (18.08, -15.98, 80.06, 96, 8, 3.38).
# The current weather summary city num:224 for hays is: (38.88, -99.33, 68.54, 54, 1, 28.86).
# Current city object for mys shmidta: not found.
# The current weather summary city num:225 for los llanos de aridane is: (28.66, -17.92, 71.6, 78, 68, 6.93).
# The current weather summary city num:226 for svetlaya is: (46.54, 138.33, 59.81, 87, 0, 4.72).
# The current weather summary city num:227 for baracoa is: (20.35, -74.5, 78.71, 100, 44, 6.85).
# The current weather summary city num:228 for chokurdakh is: (70.62, 147.9, 31.73, 100, 80, 11.1).
# The current weather summary city num:229 for pangoa is: (-12.12, -73, 66.2, 91, 8, 2.48).
# The current weather summary city num:230 for wewak is: (-3.55, 143.63, 80.6, 100, 24, 1.81).
# The current weather summary city num:231 for panjakent is: (39.5, 67.61, 57.2, 54, 0, 4.7).
# The current weather summary city num:232 for port-cartier is: (50.03, -66.88, 44.6, 93, 90, 11.41).
# The current weather summary city num:233 for buala is: (-8.15, 159.59, 82.31, 93, 88, 6.51).
# The current weather summary city num:234 for belyy yar is: (53.6, 91.39, 42.8, 87, 0, 4.47).
# The current weather summary city num:235 for sokoto is: (13.06, 5.24, 72.68, 87, 36, 1.92).
# The current weather summary city num:236 for lasa is: (34.92, 32.53, 66.2, 77, 0, 8.05).
# Current city object for mixtequilla: not found.
# The current weather summary city num:237 for zhigansk is: (66.77, 123.37, 35.15, 100, 92, 3.83).
# Current city object for mahadday weyne: not found.
# The current weather summary city num:238 for luwingu is: (-10.26, 29.92, 73.31, 42, 100, 7.52).
# The current weather summary city num:239 for namatanai is: (-3.66, 152.44, 84.2, 100, 32, 7.4).
# The current weather summary city num:240 for shingu is: (33.72, 135.99, 68, 94, 75, 4.7).
# The current weather summary city num:241 for wukari is: (7.87, 9.78, 76.1, 92, 88, 7.85).
# The current weather summary city num:242 for half moon bay is: (37.46, -122.43, 69.04, 75, 75, 3.36).
# Current city object for inderborskiy: not found.
# The current weather summary city num:243 for sao miguel do araguaia is: (-13.28, -50.16, 78.35, 75, 8, 2.71).
# The current weather summary city num:244 for saldanha is: (41.42, -6.55, 46.31, 86, 0, 4.61).
# The current weather summary city num:245 for bouna is: (9.27, -3, 74.75, 90, 36, 5.06).
# The current weather summary city num:246 for koping is: (59.51, 15.99, 35.6, 100, 0, 8.05).
# Current city object for hurghada: not found.
# The current weather summary city num:247 for volksrust is: (-27.36, 29.88, 40.73, 100, 92, 6.06).
# The current weather summary city num:248 for chernyshevskiy is: (63.01, 112.47, 38.12, 75, 64, 7.18).
# The current weather summary city num:249 for letlhakane is: (-21.42, 25.59, 60.26, 22, 56, 9.64).
# The current weather summary city num:250 for smithers is: (54.78, -127.17, 37.4, 47, 75, 3.36).
# The current weather summary city num:251 for chalchihuites is: (23.48, -103.88, 57.11, 49, 0, 5.17).
# The current weather summary city num:252 for pawak is: (8.02, 124.26, 81.95, 67, 24, 3.04).
# The current weather summary city num:253 for dawson creek is: (55.76, -120.23, 37.11, 44, 75, 4.7).
# The current weather summary city num:254 for kralendijk is: (12.15, -68.27, 84.2, 74, 44, 12.75).
# The current weather summary city num:255 for novonukutskiy is: (53.7, 102.71, 37.4, 70, 64, 8.19).
# Current city object for kamenskoye: not found.
# The current weather summary city num:256 for varnavino is: (61.19, 46.56, 44.96, 98, 92, 10.42).
# The current weather summary city num:257 for muros is: (42.77, -9.06, 55.4, 87, 0, 4.5).
# Current city object for sentyabrskiy: not found.
# The current weather summary city num:258 for ambon is: (47.55, -2.56, 51.8, 93, 0, 3.36).
# The current weather summary city num:259 for bitung is: (1.44, 125.19, 93.2, 49, 20, 3.36).
# The current weather summary city num:260 for maningrida is: (-12.05, 134.23, 84.92, 60, 0, 13.44).
# The current weather summary city num:261 for candelaria is: (3.41, -76.35, 73.4, 78, 40, 4.7).
# The current weather summary city num:262 for labuhan is: (-2.54, 115.51, 85.1, 73, 20, 2.26).
# The current weather summary city num:263 for altus is: (34.64, -99.33, 81.34, 61, 1, 12.75).
# The current weather summary city num:264 for bartica is: (6.41, -58.62, 77, 94, 0, 6.93).
# The current weather summary city num:265 for hervey bay is: (-25.3, 152.85, 73.04, 82, 0, 6.4).
# The current weather summary city num:266 for ahipara is: (-35.17, 173.16, 59, 85, 100, 11.88).
# Current city object for alotau: not found.
# The current weather summary city num:267 for laela is: (-8.57, 32.05, 60.26, 85, 68, 2.93).
# The current weather summary city num:268 for burkburnett is: (34.1, -98.57, 80.78, 64, 1, 9.17).
# The current weather summary city num:269 for nome is: (30.04, -94.42, 77.2, 100, 1, 4.38).
# The current weather summary city num:270 for wainwright is: (52.84, -110.86, 26.6, 71, 12, 5.95).
# Current city object for karaul: not found.
# The current weather summary city num:271 for tuy hoa is: (13.08, 109.3, 76.55, 100, 92, 10.54).
# The current weather summary city num:272 for yeppoon is: (-23.13, 150.74, 82.4, 34, 0, 6.93).
# The current weather summary city num:273 for price is: (39.6, -110.81, 55.94, 93, 90, 13.87).
# The current weather summary city num:274 for bethel is: (60.79, -161.76, 50, 86, 90, 11.41).
# The current weather summary city num:275 for at-bashi is: (41.17, 75.81, 35.51, 58, 0, 2.93).
# The current weather summary city num:276 for christchurch is: (-43.53, 172.64, 69.8, 28, 44, 4.7).
# The current weather summary city num:277 for kalaleh is: (37.38, 55.49, 62.51, 83, 0, 4.16).
# The current weather summary city num:278 for santiago del estero is: (-27.8, -64.26, 63.23, 45, 80, 6.96).
# The current weather summary city num:279 for nicoya is: (10.15, -85.45, 75.2, 94, 75, 5.82).
# The current weather summary city num:280 for avarua is: (-21.21, -159.78, 75.2, 53, 40, 16.11).
# The current weather summary city num:281 for de pere is: (44.45, -88.06, 76.68, 73, 75, 14.99).
# The current weather summary city num:282 for beyneu is: (45.32, 55.19, 58.28, 47, 56, 6.73).
# The current weather summary city num:283 for camacha is: (33.08, -16.33, 67.21, 93, 20, 4.7).
# Current city object for kadykchan: not found.
# The current weather summary city num:284 for chuy is: (-33.69, -53.46, 51.8, 89, 56, 5.17).
# The current weather summary city num:285 for presidencia roque saenz pena is: (-26.79, -60.44, 62.33, 73, 68, 8.63).
# Current city object for erdemli: not found.
# The current weather summary city num:286 for kumasi is: (6.7, -1.62, 71.96, 96, 64, 3.38).
# The current weather summary city num:287 for iquique is: (-20.22, -70.14, 62.6, 82, 20, 8.05).
# The current weather summary city num:288 for conde is: (-11.81, -37.61, 75.02, 93, 92, 7.52).
# The current weather summary city num:289 for vila velha is: (-3.71, -38.6, 78.8, 78, 20, 10.29).
# The current weather summary city num:290 for kaeo is: (-35.1, 173.78, 56.39, 91, 92, 11.43).
# The current weather summary city num:291 for arraial do cabo is: (-22.97, -42.02, 77, 83, 40, 9.17).
# The current weather summary city num:292 for ubauro is: (28.16, 69.73, 75.11, 60, 0, 13.22).
# The current weather summary city num:293 for dhrangadhra is: (22.99, 71.47, 78.44, 64, 0, 4.61).
# The current weather summary city num:294 for zomin is: (39.96, 68.4, 59.45, 63, 0, 4.16).
# The current weather summary city num:295 for rosarito is: (4.91, -75.23, 72.48, 83, 90, 4.7).
# The current weather summary city num:296 for upernavik is: (72.79, -56.15, 30.11, 100, 68, 8.75).
# The current weather summary city num:297 for emerald is: (-23.53, 148.16, 83.57, 35, 32, 5.73).
# The current weather summary city num:298 for pokhara is: (28.21, 83.99, 64.94, 65, 0, 1.14).
# The current weather summary city num:299 for hay river is: (60.82, -115.79, 24.8, 92, 75, 2.24).
# The current weather summary city num:300 for novovelichkovskaya is: (45.28, 38.84, 60.8, 93, 75, 4.47).
# The current weather summary city num:301 for makakilo city is: (21.35, -158.09, 84.81, 51, 20, 6.93).
# The current weather summary city num:302 for ostend is: (50.11, 8.7, 39.45, 93, 0, 1.12).
# The current weather summary city num:303 for sao joao da barra is: (-21.64, -41.05, 73.4, 88, 0, 4.7).
# The current weather summary city num:304 for mkushi is: (-13.61, 29.4, 64.4, 71, 0, 9.19).
# The current weather summary city num:305 for bhandaria is: (22.49, 90.06, 89.78, 77, 0, 3.94).
# The current weather summary city num:306 for ukiah is: (39.15, -123.21, 66.92, 78, 90, 3.36).
# The current weather summary city num:307 for spisska nova ves is: (48.94, 20.56, 36.57, 78, 40, 3.36).
# The current weather summary city num:308 for rameswaram is: (9.28, 79.3, 76.46, 100, 92, 7.74).
# Current city object for raga: not found.
# The current weather summary city num:309 for sakaiminato is: (35.55, 133.23, 71.6, 56, 90, 17.22).
# The current weather summary city num:310 for ojinaga is: (29.56, -104.41, 77.27, 55, 36, 3.83).
# The current weather summary city num:311 for almaznyy is: (48.03, 40.04, 46.4, 85, 20, 8.52).
# The current weather summary city num:312 for champerico is: (16.38, -93.6, 78.8, 69, 40, 10.29).
# The current weather summary city num:313 for vardo is: (39.62, -77.74, 68.14, 70, 1, 6.93).
# The current weather summary city num:314 for brownfield is: (33.18, -102.27, 80.17, 56, 1, 10.29).
# The current weather summary city num:315 for markova is: (52.21, 104.21, 32, 86, 90, 20.13).
# The current weather summary city num:316 for mercedes is: (-33.25, -58.03, 49.73, 66, 0, 3.38).
# The current weather summary city num:317 for ancud is: (-41.87, -73.83, 41, 87, 12, 5.17).
# The current weather summary city num:318 for kanker is: (20.27, 81.49, 81.77, 76, 0, 4.5).
# The current weather summary city num:319 for brzeszcze is: (49.98, 19.15, 42.76, 87, 75, 9.17).
# The current weather summary city num:320 for nanortalik is: (60.14, -45.24, 35.78, 96, 24, 20.49).
# The current weather summary city num:321 for hofn is: (64.25, -15.21, 45.59, 100, 92, 15.9).
# The current weather summary city num:322 for pecos is: (31.42, -103.49, 79.48, 56, 1, 3.36).
# The current weather summary city num:323 for yantal is: (56.85, 105.25, 35.78, 77, 80, 3.71).
# The current weather summary city num:324 for ulladulla is: (-35.36, 150.48, 55.4, 100, 90, 11.41).
# The current weather summary city num:325 for codrington is: (-28.95, 153.24, 76.91, 62, 76, 3.38).
# The current weather summary city num:326 for dong hoi is: (17.48, 106.6, 78.53, 100, 92, 9.75).
# The current weather summary city num:327 for shitanjing is: (39.23, 106.34, 67.01, 16, 0, 2.37).
# The current weather summary city num:328 for vikhorevka is: (56.12, 101.17, 33.8, 69, 36, 4.47).
# The current weather summary city num:329 for port hardy is: (50.7, -127.42, 48.2, 70, 75, 3.36).
# The current weather summary city num:330 for galveston is: (40.58, -86.19, 76.37, 74, 1, 13.87).
# The current weather summary city num:331 for saint george is: (39.45, 22.34, 64.4, 88, 20, 4.7).
# The current weather summary city num:332 for talnakh is: (69.49, 88.39, 30.74, 94, 80, 18.48).
# The current weather summary city num:333 for suluq is: (31.67, 20.25, 68.54, 50, 76, 3.6).
# The current weather summary city num:334 for arroio grande is: (-32.24, -53.09, 55.04, 100, 24, 5.73).
# The current weather summary city num:335 for rongcheng is: (37.16, 122.42, 73.67, 67, 0, 9.53).
# The current weather summary city num:336 for vieste is: (41.88, 16.18, 62.6, 88, 75, 8.05).
# Current city object for kismayo: not found.
# The current weather summary city num:337 for zyryanka is: (65.73, 150.89, 32.18, 87, 32, 2.82).
# The current weather summary city num:338 for umm kaddadah is: (13.6, 26.69, 74.12, 64, 0, 9.64).
# The current weather summary city num:339 for thanesar is: (29.98, 76.83, 72.77, 92, 24, 4.5).
# The current weather summary city num:340 for mkuranga is: (-7.12, 39.21, 66.74, 91, 64, 2.37).
# The current weather summary city num:341 for salamiyah is: (35.01, 37.05, 53.33, 84, 0, 4.16).
# The current weather summary city num:342 for danane is: (7.26, -8.15, 73.04, 98, 92, 3.71).
# The current weather summary city num:343 for te anau is: (-45.41, 167.72, 44.6, 100, 100, 2.26).
# The current weather summary city num:344 for lao cai is: (22.48, 103.95, 70.07, 72, 8, 2.15).
# The current weather summary city num:345 for tecolutla is: (17.31, -98.74, 67.01, 89, 48, 1.81).
# The current weather summary city num:346 for severo-kurilsk is: (50.68, 156.12, 47.3, 96, 56, 21.83).
# The current weather summary city num:347 for visby is: (57.64, 18.3, 44.6, 81, 68, 11.41).
# The current weather summary city num:348 for aklavik is: (68.22, -135.01, 26.6, 73, 90, 9.17).
# Current city object for binabalian: not found.
# The current weather summary city num:349 for plettenberg bay is: (-34.05, 23.37, 56.3, 100, 0, 6.4).
# The current weather summary city num:350 for awjilah is: (29.14, 21.3, 82.67, 29, 76, 11.54).
# The current weather summary city num:351 for paciran is: (-6.9, 112.33, 88.16, 68, 8, 4.16).
# The current weather summary city num:352 for tual is: (-5.67, 132.75, 81.68, 96, 56, 12.21).
# The current weather summary city num:353 for donskoye is: (45.45, 41.98, 55.4, 87, 0, 6.71).
# The current weather summary city num:354 for hamilton is: (32.3, -64.78, 75.2, 83, 75, 18.34).
# The current weather summary city num:355 for sharjah is: (25.36, 55.39, 78.57, 83, 0, 4.7).
# The current weather summary city num:356 for hamamatsu is: (34.71, 137.73, 69.17, 85, 92, 6.85).
# The current weather summary city num:357 for mocuba is: (-16.84, 36.99, 67.82, 80, 0, 4.5).
# The current weather summary city num:358 for tavda is: (58.04, 65.27, 44.06, 83, 44, 3.6).
# The current weather summary city num:359 for damara is: (4.96, 18.7, 71.6, 94, 20, 2.24).
# The current weather summary city num:360 for awbari is: (26.59, 12.77, 63.95, 36, 20, 7.52).
# Current city object for umzimvubu: not found.
# The current weather summary city num:361 for reconquista is: (-29.14, -59.64, 57.2, 73, 32, 8.97).
# The current weather summary city num:362 for derzhavinsk is: (51.1, 66.31, 49.37, 52, 8, 11.21).
# The current weather summary city num:363 for san jose is: (15.79, 120.99, 81.41, 86, 8, 3.04).
# The current weather summary city num:364 for qaqortoq is: (60.72, -46.03, 35.6, 55, 12, 5.82).
# The current weather summary city num:365 for valdivia is: (-39.81, -73.25, 46.31, 84, 0, 8.97).
# The current weather summary city num:366 for elin pelin is: (42.67, 23.6, 42.8, 75, 0, 2.24).
# Current city object for warqla: not found.
# The current weather summary city num:367 for faya is: (18.39, 42.45, 62.6, 51, 0, 2.71).
# The current weather summary city num:368 for zhongshan is: (22.52, 113.37, 82.4, 37, 0, 12.75).
# The current weather summary city num:369 for srednekolymsk is: (67.46, 153.71, 33.08, 69, 88, 4.16).
# The current weather summary city num:370 for chicama is: (-7.84, -79.15, 64.4, 88, 90, 8.05).
# The current weather summary city num:371 for pitimbu is: (-7.47, -34.81, 77, 83, 40, 9.17).
# The current weather summary city num:372 for bilma is: (18.69, 12.92, 73.04, 32, 0, 2.59).
# Current city object for chardara: not found.
# The current weather summary city num:373 for muzhi is: (65.4, 64.7, 28.22, 84, 0, 5.17).
# The current weather summary city num:374 for strezhevoy is: (60.73, 77.6, 48.2, 76, 0, 11.18).
# The current weather summary city num:375 for sivaki is: (52.63, 126.75, 63.23, 49, 0, 5.95).
# The current weather summary city num:376 for aksehir is: (38.36, 31.42, 46.04, 91, 36, 2.93).
# The current weather summary city num:377 for kokoda is: (-8.88, 147.74, 67.19, 100, 88, 2.26).
# The current weather summary city num:378 for bundaberg is: (-24.87, 152.35, 71.51, 93, 0, 8.41).
# The current weather summary city num:379 for geraldton is: (49.72, -86.95, 50, 100, 90, 4.7).
# The current weather summary city num:380 for vvedenskoye is: (55.29, 38.01, 43.59, 87, 75, 6.71).
# The current weather summary city num:381 for omsukchan is: (62.53, 155.8, 27.86, 75, 92, 9.64).
# The current weather summary city num:382 for dawlatabad is: (36.41, 64.91, 58.28, 56, 0, 3.94).
# The current weather summary city num:383 for poum is: (41.28, 20.71, 44.51, 95, 32, 1.7).
# The current weather summary city num:384 for nador is: (35.17, -2.93, 57.2, 76, 0, 2.24).
# The current weather summary city num:385 for adolfo lopez mateos is: (26.8, -109.39, 84.56, 54, 12, 3.94).
# The current weather summary city num:386 for swan hill is: (-35.34, 143.56, 64.13, 57, 0, 17.69).
# The current weather summary city num:387 for kabare is: (-1.65, 29.38, 58.91, 100, 88, 3.71).
# The current weather summary city num:388 for helena is: (46.59, -112.04, 42.08, 11, 1, 4.7).
# The current weather summary city num:389 for lappersdorf is: (49.05, 12.09, 40.21, 93, 0, 3.6).
# The current weather summary city num:390 for san cristobal is: (-0.39, -78.55, 51.8, 87, 75, 8.05).
# The current weather summary city num:391 for samarai is: (-10.62, 150.67, 77.63, 100, 44, 12.77).
# Current city object for devyatka: not found.
# The current weather summary city num:392 for xinzhou is: (38.41, 112.73, 63.86, 44, 0, 3.38).
# The current weather summary city num:393 for porto novo is: (-23.68, -45.44, 68, 100, 75, 3.36).
# The current weather summary city num:394 for billings is: (45.79, -108.5, 37.94, 14, 1, 9.17).
# The current weather summary city num:395 for olinda is: (-2.03, -79.75, 73.4, 78, 75, 17.22).
# Current city object for bacuit: not found.
# The current weather summary city num:396 for vila franca do campo is: (37.72, -25.43, 69.8, 77, 75, 6.93).
# The current weather summary city num:397 for nouadhibou is: (20.93, -17.03, 78.8, 57, 68, 14.99).
# The current weather summary city num:398 for dukat is: (42.44, 22.31, 37.58, 85, 0, 1.7).
# The current weather summary city num:399 for sambava is: (-14.27, 50.17, 71.69, 100, 92, 6.06).
# The current weather summary city num:400 for palana is: (59.08, 159.95, 42.44, 83, 92, 7.52).
# The current weather summary city num:401 for belaya gora is: (68.54, 146.19, 30.38, 97, 36, 4.61).
# The current weather summary city num:402 for bathsheba is: (13.22, -59.52, 82.4, 83, 40, 10.29).
# The current weather summary city num:403 for lazo is: (47.89, 27.93, 42.8, 86, 8, 11.99).
# The current weather summary city num:404 for olenegorsk is: (68.14, 33.28, 28.31, 100, 0, 4.38).
# The current weather summary city num:405 for altay is: (47.83, 88.13, 32.36, 71, 0, 3.15).
# The current weather summary city num:406 for manggar is: (-2.88, 108.27, 88.88, 68, 0, 12.66).
# Current city object for xiongshi: not found.
# The current weather summary city num:407 for bima is: (-8.45, 118.73, 84.29, 69, 56, 3.71).
# The current weather summary city num:408 for antofagasta is: (-23.65, -70.4, 59, 77, 90, 1.12).
# The current weather summary city num:409 for yeniseysk is: (58.45, 92.17, 40.46, 88, 88, 4.27).
# The current weather summary city num:410 for tautira is: (-17.73, -149.15, 80.6, 57, 40, 11.41).
# The current weather summary city num:411 for innisfail is: (52.02, -113.95, 30.2, 74, 90, 3.36).
# The current weather summary city num:412 for peniche is: (39.36, -9.38, 60.1, 32, 0, 2.24).
# The current weather summary city num:413 for acapulco is: (16.86, -99.88, 82.4, 83, 75, 6.93).
# The current weather summary city num:414 for arona is: (45.76, 8.56, 50.02, 93, 0, 6.93).
# The current weather summary city num:415 for kondinskoye is: (59.65, 67.41, 46.94, 74, 92, 6.4).
# The current weather summary city num:416 for burnie is: (-41.05, 145.91, 51.08, 100, 24, 3.49).
# The current weather summary city num:417 for verkhoyansk is: (67.55, 133.39, 28.31, 69, 56, 3.6).
# Current city object for litoral del san juan: not found.
# The current weather summary city num:418 for timbiqui is: (2.77, -77.67, 73.94, 100, 92, 2.15).
# The current weather summary city num:419 for tiznit is: (29.7, -9.73, 66.29, 95, 44, 1.48).
# The current weather summary city num:420 for makaha is: (21.47, -158.22, 84.85, 67, 20, 13.87).
# The current weather summary city num:421 for soyo is: (-6.13, 12.37, 74.21, 91, 64, 3.6).
# Current city object for palabuhanratu: not found.
# The current weather summary city num:422 for laurel is: (45.67, -108.77, 37.94, 14, 1, 9.17).
# The current weather summary city num:423 for thunder bay is: (48.41, -89.26, 53.6, 100, 90, 5.82).
# The current weather summary city num:424 for gazojak is: (41.19, 61.4, 56.3, 62, 0, 4.5).
# The current weather summary city num:425 for areosa is: (41.72, -8.86, 63.5, 51, 0, 3.36).
# The current weather summary city num:426 for mount gambier is: (-37.83, 140.78, 58.91, 66, 0, 8.19).
# The current weather summary city num:427 for muisne is: (0.61, -80.02, 70.88, 92, 36, 6.96).
# The current weather summary city num:428 for taoudenni is: (22.68, -3.98, 76.1, 31, 20, 5.61).
# The current weather summary city num:429 for rabak is: (13.18, 32.74, 74.03, 81, 24, 3.38).
# The current weather summary city num:430 for auki is: (12.18, 6.51, 71.06, 88, 12, 6.73).
# The current weather summary city num:431 for haradok is: (55.46, 29.99, 44.33, 97, 92, 15.23).
# The current weather summary city num:432 for amol is: (36.47, 52.35, 67.19, 100, 32, 1.14).
# The current weather summary city num:433 for zadar is: (44.12, 15.24, 64.4, 36, 0, 8.05).
# Current city object for ituni: not found.
# The current weather summary city num:434 for viedma is: (-40.81, -62.99, 41.18, 60, 0, 2.93).
# The current weather summary city num:435 for nalut is: (31.86, 10.98, 46.58, 80, 0, 2.71).
# The current weather summary city num:436 for ostrovnoy is: (68.05, 39.51, 22.73, 87, 0, 10.09).
# The current weather summary city num:437 for taikang is: (46.86, 124.44, 69.89, 51, 0, 13.67).
# The current weather summary city num:438 for bandar-e lengeh is: (26.56, 54.88, 80.6, 100, 20, 4.7).
# The current weather summary city num:439 for pangnirtung is: (66.15, -65.72, 25.88, 88, 88, 11.43).
# The current weather summary city num:440 for abu dhabi is: (24.47, 54.37, 82.4, 83, 0, 4.94).
# The current weather summary city num:441 for riyadh is: (24.63, 46.72, 71.6, 24, 0, 2.71).
# The current weather summary city num:442 for kikwit is: (-5.04, 18.82, 67.64, 99, 48, 3.38).
# The current weather summary city num:443 for kempten is: (47.33, 8.82, 47.93, 100, 32, 2.48).
# The current weather summary city num:444 for bonavista is: (48.65, -53.11, 46.22, 100, 0, 13.56).
# The current weather summary city num:445 for cabedelo is: (-6.97, -34.84, 77, 83, 40, 9.17).
# The current weather summary city num:446 for kupang is: (-10.16, 123.6, 89.6, 49, 20, 9.17).
# The current weather summary city num:447 for san isidro is: (16.74, 121.63, 83.75, 83, 0, 3.04).
# The current weather summary city num:448 for amahai is: (-3.31, 129, 80.33, 100, 64, 10.2).
# The current weather summary city num:449 for mecca is: (21.43, 39.83, 69.08, 69, 48, 2.71).
# Current city object for kegayli: not found.
# The current weather summary city num:450 for puerto lleras is: (8.16, -72.46, 75.2, 100, 75, 6.93).
# Current city object for bardiyah: not found.
# Current city object for haibowan: not found.
# The current weather summary city num:451 for quelimane is: (-17.88, 36.89, 66.74, 92, 0, 3.94).
# The current weather summary city num:452 for ati is: (13.21, 18.34, 76.37, 68, 0, 6.73).
# The current weather summary city num:453 for batagay-alyta is: (67.8, 130.41, 23.36, 91, 56, 3.38).
# The current weather summary city num:454 for puerto carreno is: (6.19, -67.49, 80.6, 83, 40, 3.15).
# The current weather summary city num:455 for iquitos is: (-3.75, -73.25, 75.2, 94, 40, 1.59).
# The current weather summary city num:456 for carutapera is: (-1.2, -46.02, 79.61, 80, 68, 10.54).
# The current weather summary city num:457 for bose is: (45.46, 8.01, 52.57, 76, 0, 4.7).
# The current weather summary city num:458 for rorvik is: (64.86, 11.24, 43.34, 100, 76, 4.05).
# The current weather summary city num:459 for beaufort is: (5.36, 115.76, 87.62, 70, 75, 5.82).
# The current weather summary city num:460 for goderich is: (43.74, -81.71, 67.37, 90, 20, 23.96).
# The current weather summary city num:461 for joaima is: (-16.65, -41.03, 71.6, 76, 0, 7.85).
# The current weather summary city num:462 for hirara is: (24.8, 125.28, 77, 94, 75, 48.32).
# The current weather summary city num:463 for blackfoot is: (43.19, -112.35, 58.64, 56, 40, 8.05).
# The current weather summary city num:464 for victoria point is: (-27.58, 153.3, 75.85, 56, 20, 18.34).
# The current weather summary city num:465 for broken hill is: (-31.97, 141.45, 60.62, 93, 20, 20.49).
# The current weather summary city num:466 for terme is: (41.21, 36.97, 62.6, 88, 75, 2.24).
# The current weather summary city num:467 for mayo is: (63.59, -135.9, 32, 83, 40, 0.58).
# The current weather summary city num:468 for tallahassee is: (30.44, -84.28, 73.85, 94, 20, 4.38).
# The current weather summary city num:469 for talcahuano is: (-36.72, -73.12, 57.2, 47, 0, 14.99).
# The current weather summary city num:470 for palauig is: (15.44, 119.9, 82.94, 84, 8, 5.95).
# The current weather summary city num:471 for troitskiy is: (45.15, 38.14, 59, 77, 92, 2.24).
# The current weather summary city num:472 for kudahuvadhoo is: (2.67, 72.89, 82.4, 100, 36, 23.29).
# The current weather summary city num:473 for tanout is: (14.97, 8.88, 77.63, 56, 56, 2.26).
# Current city object for ayer itam: not found.
# The current weather summary city num:474 for thinadhoo is: (0.53, 72.93, 81.14, 100, 64, 20.04).
# The current weather summary city num:475 for naze is: (5.43, 7.07, 73.31, 99, 76, 2.93).
# The current weather summary city num:476 for sabang is: (13.72, 123.58, 82.76, 94, 24, 4.72).
# The current weather summary city num:477 for samoded is: (63.61, 40.52, 33.35, 92, 56, 4.94).
# The current weather summary city num:478 for roebourne is: (-20.77, 117.15, 98.15, 17, 12, 7.29).
# The current weather summary city num:479 for redditch is: (52.31, -1.94, 54.07, 93, 0, 4.7).
# The current weather summary city num:480 for saint-georges is: (46.12, -70.67, 40.46, 89, 48, 2.82).
# The current weather summary city num:481 for manakara is: (-22.14, 48.01, 67.73, 99, 64, 7.52).
# The current weather summary city num:482 for eureka is: (40.8, -124.16, 55.67, 86, 90, 5.17).
# Current city object for balykshi: not found.
# The current weather summary city num:483 for apac is: (1.98, 32.53, 63.77, 100, 56, 4.05).
# Current city object for asau: not found.
# The current weather summary city num:484 for kysyl-syr is: (63.9, 122.77, 40.1, 74, 44, 7.07).
# The current weather summary city num:485 for kachiry is: (53.07, 76.1, 42.71, 77, 0, 8.75).
# The current weather summary city num:486 for henties bay is: (-22.12, 14.28, 59.63, 91, 0, 7.96).
# The current weather summary city num:487 for fernley is: (39.61, -119.25, 54.9, 76, 75, 11.41).
# The current weather summary city num:488 for prado is: (-17.34, -39.22, 77.36, 97, 12, 15.79).
# The current weather summary city num:489 for dafeng is: (33.2, 120.46, 75.56, 66, 8, 11.88).
# The current weather summary city num:490 for tawang is: (27.59, 91.87, 53.51, 43, 0, 1.48).
# The current weather summary city num:491 for la macarena is: (2.18, -73.79, 73.49, 92, 0, 1.59).
# The current weather summary city num:492 for kardla is: (58.44, 26.57, 42.8, 87, 90, 13.87).
# The current weather summary city num:493 for santa marta is: (11.24, -74.21, 80.6, 94, 40, 6.93).
# The current weather summary city num:494 for raton is: (36.9, -104.44, 69.64, 50, 75, 12.75).
# The current weather summary city num:495 for buraydah is: (26.33, 43.97, 68, 40, 0, 3.36).
# Current city object for armacao dos buzios: not found.
# The current weather summary city num:496 for pimentel is: (-3.7, -45.5, 78.71, 75, 8, 6.51).
# The current weather summary city num:497 for aswan is: (24.09, 32.9, 84.2, 30, 0, 8.05).
# The current weather summary city num:498 for mago is: (53.27, 140.15, 55.31, 55, 0, 8.41).
# The current weather summary city num:499 for zakamensk is: (50.38, 103.29, 25.88, 67, 88, 13.78).
# The current weather summary city num:500 for itaporanga is: (-7.3, -38.15, 81.86, 41, 80, 8.41).
# The current weather summary city num:501 for iskateley is: (67.68, 53.15, 38.84, 98, 64, 15.12).
# The current weather summary city num:502 for sorland is: (67.67, 12.69, 42.71, 100, 56, 6.62).
# The current weather summary city num:503 for alice springs is: (-23.7, 133.88, 75.2, 31, 0, 13.87).
# The current weather summary city num:504 for gorontalo is: (0.54, 123.06, 88.88, 55, 24, 3.71).
# The current weather summary city num:505 for yerbogachen is: (61.28, 108.01, 38.84, 61, 64, 6.73).
# The current weather summary city num:506 for ampanihy is: (-24.69, 44.75, 61.16, 94, 92, 3.15).
# The current weather summary city num:507 for karwar is: (14.8, 74.13, 77.18, 85, 8, 2.48).
# The current weather summary city num:508 for hanusovice is: (50.08, 16.94, 42.17, 89, 8, 8.75).
# The current weather summary city num:509 for moron is: (10.49, -68.2, 69.98, 91, 8, 2.48).
# The current weather summary city num:510 for bokaa is: (-24.43, 26.02, 59, 41, 0, 9.17).
# Current city object for teluk nibung: not found.
# The current weather summary city num:511 for twin falls is: (42.57, -114.46, 60.75, 68, 20, 3.36).
# The current weather summary city num:512 for havelock is: (34.88, -76.9, 75.47, 87, 1, 9.31).
# The current weather summary city num:513 for avera is: (33.19, -82.53, 75.52, 87, 90, 5.61).
# The current weather summary city num:514 for itaituba is: (-4.26, -55.99, 77.72, 84, 0, 1.92).
# The current weather summary city num:515 for wajid is: (3.81, 43.25, 68.81, 84, 0, 10.87).
# The current weather summary city num:516 for seddon is: (-41.67, 174.07, 60.26, 71, 8, 12.21).
# The current weather summary city num:517 for panaba is: (21.28, -88.27, 76.73, 91, 20, 4.5).
# The current weather summary city num:518 for havre is: (48.55, -109.68, 32, 18, 1, 4.7).
# The current weather summary city num:519 for himatnagar is: (23.6, 72.96, 80.6, 78, 0, 3.71).
# The current weather summary city num:520 for milisauti is: (47.78, 26, 46, 75, 0, 8.05).
# The current weather summary city num:521 for pascagoula is: (30.37, -88.56, 79.07, 100, 1, 4.5).
# The current weather summary city num:522 for mumford is: (5.26, -0.76, 75.11, 97, 12, 5.95).
# The current weather summary city num:523 for verkhnevilyuysk is: (63.45, 120.31, 41.36, 69, 64, 8.19).

# %%
#print(weather_data)
print(len(weather_data))
# Out:
# 523

# %%
column_names = ["Latitude", "Longitude", "Temperature(F)", "Humidity%", "Clouds%", "Wind Speed(mph)"]
weather = pd.DataFrame(weather_data, index=cities, columns=column_names)
weather.head()
# Out:
#                 Latitude  Longitude  Temperature(F)  Humidity%  Clouds%  \
# russell           -33.01     -68.80           60.80         44        0
# east london       -33.02      27.91           60.53        100       88
# shakawe           -18.36      21.84           56.30         37        0
# cabo san lucas     22.89    -109.91           81.59         74        5
# lompoc             34.64    -120.46           66.31         89       90
#
#                 Wind Speed(mph)
# russell                    3.36
# east london                9.75
# shakawe                    2.71
# cabo san lucas             6.93
# lompoc                     3.36

# %%
weather.to_csv("WeatherPy_Output/WorldWeatherData.csv", index=False)

# %%
# %matplotlib notebook
x_values = weather["Latitude"]
y_temp_values = weather["Temperature(F)"]
plt.scatter(x_values,y_temp_values, c = y_temp_values, edgecolor="black", linewidths=1, marker="o", 
            cmap='plasma',alpha=0.8, label="City")

# Incorporate the other graph properties
plt.style.use('seaborn')
plt.title(f"City Latitude vs. Max Temperature {time.strftime('%m/%d/%Y')}")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-70, 90])
plt.ylim([-10, 110])

# Save the figure
plt.savefig("WeatherPy_Output/Latitude_Temperature.png")
#plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# %matplotlib notebook
x_values = weather["Latitude"]
y_humidity_values = weather["Humidity%"]
plt.scatter(x_values,y_humidity_values, c= y_humidity_values, edgecolor="black", linewidths=1, marker="o", 
            cmap='GnBu',alpha=0.8, label="City")


plt.style.use('seaborn')
plt.title(f"City Latitude vs. Humidity % {time.strftime('%m/%d/%Y')}")
plt.ylabel("Humidity %")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-80, 100])
plt.ylim([-5, 125])
plt.savefig("WeatherPy_Output/Latitude_Humidity.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# %matplotlib notebook
x_values = weather["Longitude"]
y_humidity_values = weather["Humidity%"]
plt.scatter(x_values,y_humidity_values, c= y_humidity_values, edgecolor="black", linewidths=1, marker="o", 
            cmap='winter',alpha=0.8, label="City")
plt.style.use('seaborn')
plt.title(f"City Longitude vs. Humidity% {time.strftime('%m/%d/%Y')}")
plt.ylabel("Humidity %")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-180, 180])
plt.ylim([0, 110])
plt.savefig("WeatherPy_Output/Longitude_Humidity.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# %matplotlib notebook
x_values = weather["Latitude"]
y_clouds_values = weather["Clouds%"]
plt.scatter(x_values,y_clouds_values, c= y_clouds_values, edgecolor="black", linewidths=1, marker="o", 
            cmap='autumn',alpha=0.8, label="City")
plt.style.use('seaborn')
plt.title(f"City Latitude vs. Clouds % {time.strftime('%m/%d/%Y')}")
plt.ylabel("Clouds %")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-70, 90])
plt.ylim([-5, 105])
plt.savefig("WeatherPy_Output/Latitude_Clouds.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# %matplotlib notebook
x_values = weather["Latitude"]
y_wind_values = weather["Wind Speed(mph)"]
plt.scatter(x_values,y_wind_values, c= y_wind_values, edgecolor="black", linewidths=1, marker="o", 
            cmap='gist_earth',alpha=0.8, label="City")
plt.style.use('seaborn')
plt.title(f"City Latitude vs. Wind Speed(mph) {time.strftime('%m/%d/%Y')}")
plt.ylabel("Wind Speed(mph)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-70, 90])
plt.ylim([-1, 30])
plt.savefig("WeatherPy_Output/Latitude_WindSpeed.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# As a short analysis:
# **Temparature tends to get higher when the latitude gets cloder to 0.
# **Humidity does not have a pattern with latitude, but it seems that the humidity doesn't get lower than 40% around latitude 0.
# **Cloud percent has an interesting plot. It doesn't seem completly scattered, rather cloud values seem to be collected around certain percentages but distributed along many different latitude values. (It looks like a few clouds percent is equal to some value no matter what latitude line is drawn.)(a few different y=a lines)
