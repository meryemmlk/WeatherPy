# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import API key

import api_keys
from api_keys import gkey


# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy
# Dependencies
import openweathermapy as owm

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
first_cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1550)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1550)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in first_cities:
        first_cities.append(city)

# Print the city count to confirm sufficient count
len(first_cities)
# Out:
# 622

# %% [markdown]
# ## Perform API Calls

# %%
# OpenWeatherMap API Key
api_key = api_keys.api_key

# Create settings dictionary with information we're interested in
settings = {"units": "imperial", "appid": api_key}

#for city in cities:
#    try:
#        current_weather_city = owm.get_current(city, **settings)
#    except:
#        cities.remove(city)
#print(len(cities))

# Get current weather
weather_data = []
num = 0
cities = []
for city in first_cities:
    try:
        current_weather_city = owm.get_current(city, **settings)
        #print(f"Current weather object for {city}: {current_weather_city}.")
        summary = ["coord.lat", "coord.lon", "main.temp", "main.humidity", "clouds.all", "wind.speed"]
        data = current_weather_city(*summary)
        print(f"The current weather summary for {city} is: {data}.")
        weather_data.append(data)
        #print(weather_data)
        cities.append(city)
        num += 1
    except:
        print(f"Current city object for {city}: not found.")
        first_cities.remove(city)
        
print(num)
print(len(cities))
print(len(first_cities))
# Out:
# The current weather summary for kurilsk is: (45.23, 147.88, 53.64, 100, 92, 10.04).
# The current weather summary for ushuaia is: (-54.81, -68.31, 35.6, 69, 40, 17.22).
# The current weather summary for cururupu is: (-1.82, -44.87, 80.01, 79, 36, 9.26).
# The current weather summary for katsuura is: (33.93, 134.5, 66.2, 72, 20, 5.82).
# The current weather summary for mayumba is: (-3.44, 10.65, 74.7, 99, 92, 6.46).
# The current weather summary for castro is: (-42.48, -73.76, 44.55, 99, 92, 6.46).
# The current weather summary for bambous virieux is: (-20.34, 57.76, 71.6, 83, 40, 10.29).
# The current weather summary for gannan is: (47.92, 123.49, 53.19, 58, 0, 12.84).
# The current weather summary for bathsheba is: (13.22, -59.52, 80.6, 78, 20, 10.29).
# The current weather summary for rikitea is: (-23.12, -134.97, 70.47, 100, 88, 11.5).
# The current weather summary for jamestown is: (-33.21, 138.6, 77.49, 21, 68, 10.49).
# The current weather summary for mar del plata is: (-46.43, -67.52, 49.32, 45, 56, 14.52).
# The current weather summary for gobabis is: (-22.45, 18.97, 73.4, 33, 0, 3.36).
# The current weather summary for cairns is: (-16.92, 145.77, 75.2, 69, 75, 17.22).
# The current weather summary for codrington is: (-28.95, 153.24, 67.32, 73, 0, 4.56).
# The current weather summary for pundaguitan is: (6.37, 126.17, 82.62, 100, 24, 3.67).
# The current weather summary for hovd is: (63.83, 10.7, 36.55, 93, 0, 9.17).
# The current weather summary for baracoa is: (20.35, -74.5, 77.94, 100, 76, 8.48).
# The current weather summary for fairbanks is: (64.84, -147.72, 67.23, 6, 1, 10.29).
# Current city object for barentsburg: not found.
# The current weather summary for ilo is: (-17.65, -71.34, 57.51, 99, 32, 2.77).
# The current weather summary for flic en flac is: (-20.27, 57.36, 71.6, 83, 40, 10.29).
# The current weather summary for mataura is: (-46.19, 168.86, 47.79, 97, 80, 15.52).
# The current weather summary for cherskiy is: (68.75, 161.3, 43.2, 67, 68, 3).
# The current weather summary for busselton is: (-33.64, 115.35, 56.88, 100, 0, 18.21).
# The current weather summary for victoria is: (5.28, 115.24, 80.6, 94, 75, 6.35).
# The current weather summary for poum is: (41.28, 20.71, 38.79, 88, 0, 1.66).
# The current weather summary for longyearbyen is: (78.22, 15.63, 30.2, 63, 75, 10.29).
# The current weather summary for tiksi is: (71.64, 128.87, 25.38, 100, 64, 4.45).
# The current weather summary for yerbogachen is: (61.28, 108.01, 37.89, 75, 80, 5.46).
# The current weather summary for khatanga is: (71.98, 102.47, 32.85, 95, 44, 3.67).
# The current weather summary for requena is: (39.49, -1.1, 64.4, 63, 0, 9.17).
# The current weather summary for torbay is: (47.66, -52.73, 48.2, 81, 75, 11.41).
# Current city object for urumqi: not found.
# The current weather summary for punta arenas is: (-53.16, -70.91, 39.2, 100, 75, 23.04).
# The current weather summary for georgetown is: (6.8, -58.16, 79.47, 79, 0, 6.8).
# The current weather summary for saldanha is: (41.42, -6.55, 54.72, 52, 44, 9.93).
# The current weather summary for assen is: (53, 6.56, 45.1, 93, 90, 6.93).
# The current weather summary for mittagong is: (-34.45, 150.45, 66.2, 59, 0, 3.22).
# The current weather summary for vila is: (45.18, 8.4, 50.14, 57, 0, 5.82).
# The current weather summary for rocha is: (-34.48, -54.34, 44.73, 85, 0, 6.46).
# The current weather summary for kapaa is: (22.08, -159.32, 81.45, 79, 90, 5.82).
# The current weather summary for souillac is: (45.6, -0.6, 49.01, 57, 0, 2.24).
# The current weather summary for hermanus is: (-34.42, 19.24, 54.27, 97, 92, 7.47).
# Current city object for olafsvik: not found.
# The current weather summary for provideniya is: (64.42, -173.23, 51.8, 87, 90, 8.95).
# Current city object for kracheh: not found.
# The current weather summary for pomabamba is: (-8.82, -77.46, 50.85, 53, 24, 1.54).
# The current weather summary for klamath falls is: (42.22, -121.78, 60.08, 57, 90, 10.29).
# The current weather summary for ponta do sol is: (-20.63, -46, 65.79, 97, 88, 2.21).
# The current weather summary for camacha is: (33.08, -16.33, 72.63, 73, 75, 6.93).
# The current weather summary for zhezkazgan is: (47.8, 67.71, 53.6, 54, 90, 6.71).
# The current weather summary for pakxan is: (18.39, 103.66, 70.74, 83, 20, 3.22).
# The current weather summary for namibe is: (-15.19, 12.15, 65.97, 100, 88, 2.77).
# Current city object for illoqqortoormiut: not found.
# The current weather summary for chiredzi is: (-21.05, 31.67, 56.79, 81, 0, 2.77).
# The current weather summary for isilkul is: (54.9, 71.26, 40.68, 74, 88, 8.25).
# The current weather summary for naze is: (5.43, 7.07, 73.71, 97, 92, 5.57).
# The current weather summary for yulin is: (38.3, 109.75, 38.25, 68, 0, 4.79).
# The current weather summary for krutinka is: (56.01, 71.51, 39.6, 85, 44, 8.48).
# The current weather summary for russell is: (-33.01, -68.8, 55.4, 43, 0, 6.93).
# The current weather summary for yellowknife is: (62.45, -114.38, 33.8, 47, 75, 18.34).
# The current weather summary for sosua is: (19.77, -70.52, 81.41, 83, 75, 5.82).
# The current weather summary for omagh is: (54.6, -7.3, 55.4, 100, 90, 19.46).
# The current weather summary for oktyabrskiy is: (55.61, 37.97, 41.43, 80, 0, 6.71).
# The current weather summary for simao is: (22.76, 100.79, 61.74, 99, 92, 2.89).
# The current weather summary for puerto madryn is: (-42.77, -65.04, 56.07, 56, 32, 16.08).
# The current weather summary for ostrovnoy is: (68.05, 39.51, 33.39, 95, 68, 9.93).
# The current weather summary for thompson is: (55.74, -97.86, 37.4, 44, 90, 6.93).
# The current weather summary for barrow is: (-38.31, -60.23, 39.06, 42, 0, 4).
# The current weather summary for blackwater is: (51.33, -0.78, 49.3, 71, 64, 11.41).
# The current weather summary for port alfred is: (-33.59, 26.89, 65.61, 100, 80, 8.14).
# The current weather summary for partizanskoye is: (44.83, 34.08, 54, 96, 36, 2.44).
# The current weather summary for clifton is: (-27.93, 151.91, 66.2, 48, 0, 17.22).
# The current weather summary for walvis bay is: (-22.95, 14.51, 53.6, 87, 0, 9.17).
# The current weather summary for portland is: (45.52, -122.67, 69.48, 47, 90, 5.82).
# The current weather summary for qaanaaq is: (77.48, -69.36, 14.49, 100, 0, 13.29).
# The current weather summary for cape town is: (-33.93, 18.42, 57.2, 76, 40, 9.17).
# The current weather summary for harper is: (30.3, -99.24, 80.56, 60, 75, 5.82).
# The current weather summary for jaciara is: (-15.95, -54.98, 75.24, 90, 36, 2.77).
# Current city object for amderma: not found.
# The current weather summary for hilo is: (19.71, -155.08, 79.09, 59, 1, 10.29).
# The current weather summary for clayton is: (36.45, -103.19, 84.02, 21, 20, 17.22).
# Current city object for artyk: not found.
# Current city object for mys shmidta: not found.
# The current weather summary for araouane is: (18.9, -3.53, 86.04, 30, 80, 9.26).
# Current city object for kushmurun: not found.
# The current weather summary for puerto ayora is: (-0.74, -90.35, 72.45, 100, 0, 11.83).
# The current weather summary for saint-philippe is: (45.36, -73.48, 49.26, 57, 1, 2.24).
# Current city object for attawapiskat: not found.
# The current weather summary for chicama is: (-7.84, -79.15, 66.24, 85, 36, 4.79).
# The current weather summary for axim is: (4.87, -2.24, 78.12, 98, 20, 10.38).
# The current weather summary for namatanai is: (-3.66, 152.44, 84.69, 95, 12, 6.02).
# The current weather summary for cayenne is: (4.94, -52.33, 78.8, 94, 40, 7.92).
# The current weather summary for butaritari is: (3.07, 172.79, 84.33, 100, 76, 5.23).
# The current weather summary for san cristobal is: (-0.39, -78.55, 48.24, 100, 92, 1.88).
# Current city object for jurado: not found.
# The current weather summary for kununurra is: (-15.77, 128.74, 80.6, 65, 0, 8.05).
# The current weather summary for osterhofen is: (48.7, 13.02, 41.04, 90, 20, 8.7).
# Current city object for grand river south east: not found.
# The current weather summary for meadow lake is: (54.13, -108.44, 39.2, 48, 75, 3.36).
# The current weather summary for ust-kut is: (56.78, 105.75, 39.78, 72, 56, 4.12).
# The current weather summary for atuona is: (-9.8, -139.03, 79.47, 100, 0, 11.5).
# The current weather summary for albany is: (42.65, -73.75, 52.95, 86, 90, 6.93).
# The current weather summary for saskylakh is: (71.97, 114.09, 29.97, 97, 92, 6.24).
# The current weather summary for sao filipe is: (14.9, -24.5, 77.22, 100, 88, 13.51).
# The current weather summary for makakilo city is: (21.35, -158.09, 85.01, 70, 40, 4.7).
# The current weather summary for nanortalik is: (60.14, -45.24, 36.45, 99, 80, 0.76).
# The current weather summary for dobele is: (56.63, 23.28, 42.8, 93, 0, 5.82).
# The current weather summary for dikson is: (73.51, 80.55, 38.25, 100, 76, 18.32).
# The current weather summary for kruisfontein is: (-34, 24.73, 60.84, 92, 68, 11.95).
# The current weather summary for lompoc is: (34.64, -120.46, 74.61, 72, 75, 13.87).
# The current weather summary for maple creek is: (49.91, -109.46, 47.25, 72, 44, 4.12).
# The current weather summary for bredasdorp is: (-34.53, 20.04, 57.2, 87, 64, 13.87).
# The current weather summary for san quintin is: (17.54, 120.52, 77, 69, 20, 4.7).
# The current weather summary for coihaique is: (-45.58, -72.07, 42.55, 45, 75, 5.82).
# The current weather summary for airai is: (-8.93, 125.41, 67.59, 89, 80, 1.66).
# The current weather summary for itarema is: (-2.92, -39.92, 77.94, 76, 0, 16.64).
# The current weather summary for angoche is: (-16.23, 39.91, 75.42, 100, 0, 3.78).
# The current weather summary for ponta delgada is: (37.73, -25.67, 69.8, 73, 40, 12.75).
# Current city object for fort saint john: not found.
# The current weather summary for banatsko novo selo is: (44.99, 20.78, 52.41, 87, 0, 1.12).
# The current weather summary for upernavik is: (72.79, -56.15, 36.99, 94, 68, 18.88).
# The current weather summary for kodiak is: (39.95, -94.76, 62.06, 89, 90, 4.7).
# The current weather summary for chuy is: (-33.69, -53.46, 53.46, 85, 88, 15.97).
# The current weather summary for new norfolk is: (-42.78, 147.06, 59, 62, 40, 5.82).
# The current weather summary for egvekinot is: (66.32, -179.17, 47.07, 100, 92, 6.69).
# The current weather summary for norman wells is: (65.28, -126.83, 35.6, 64, 20, 16.11).
# The current weather summary for east london is: (-33.02, 27.91, 69.21, 100, 36, 12.28).
# The current weather summary for port hardy is: (50.7, -127.42, 51.8, 93, 90, 4.7).
# The current weather summary for srednekolymsk is: (67.46, 153.71, 34.65, 77, 24, 6.13).
# Current city object for yanan: not found.
# The current weather summary for kondinskoye is: (59.65, 67.41, 36.81, 95, 8, 7.14).
# The current weather summary for flinders is: (-34.58, 150.85, 66.2, 59, 0, 3.56).
# The current weather summary for berlevag is: (70.86, 29.09, 37.4, 64, 75, 23.04).
# The current weather summary for college is: (64.86, -147.8, 67.23, 6, 1, 10.29).
# The current weather summary for aguada de pasajeros is: (22.38, -80.85, 80.6, 78, 76, 8.05).
# The current weather summary for asosa is: (10.07, 34.53, 63.27, 91, 76, 2.66).
# The current weather summary for shache is: (38.42, 77.24, 39.42, 85, 0, 3.67).
# The current weather summary for poso is: (-1.4, 120.75, 79.29, 100, 24, 4.68).
# The current weather summary for tuktoyaktuk is: (69.44, -133.03, 28.4, 92, 75, 8.05).
# The current weather summary for paamiut is: (61.99, -49.67, 38.61, 95, 36, 9.6).
# The current weather summary for pangnirtung is: (66.15, -65.72, 24.93, 85, 56, 9.04).
# The current weather summary for goderich is: (43.74, -81.71, 50.94, 98, 92, 15.52).
# The current weather summary for thunder bay is: (48.41, -89.26, 44.6, 81, 75, 5.82).
# The current weather summary for mehamn is: (71.03, 27.85, 37.4, 64, 75, 23.04).
# The current weather summary for meulaboh is: (4.14, 96.13, 77.04, 100, 88, 3.78).
# Current city object for tsihombe: not found.
# The current weather summary for karratha is: (-20.74, 116.85, 70.11, 66, 32, 7.92).
# The current weather summary for kudeyevskiy is: (54.87, 56.75, 39.2, 80, 0, 11.18).
# The current weather summary for kiunga is: (-6.12, 141.3, 81.54, 80, 48, 3).
# Current city object for rawannawi: not found.
# The current weather summary for kisangani is: (0.52, 25.21, 74.16, 96, 88, 2.55).
# The current weather summary for beringovskiy is: (63.05, 179.32, 45.45, 100, 12, 4.23).
# The current weather summary for sao joao da barra is: (-21.64, -41.05, 77, 78, 0, 9.17).
# The current weather summary for dingle is: (11, 122.67, 82.35, 76, 0, 3.67).
# Current city object for cumaribo: not found.
# The current weather summary for treinta y tres is: (-33.23, -54.39, 50.13, 78, 68, 9.6).
# The current weather summary for wielun is: (51.22, 18.57, 46.98, 83, 68, 10.6).
# The current weather summary for whitehorse is: (60.72, -135.06, 48.2, 26, 20, 8.05).
# The current weather summary for santa cruz is: (36.97, -122.03, 74.48, 44, 1, 11.41).
# Current city object for babanusah: not found.
# Current city object for belushya guba: not found.
# Current city object for bengkulu: not found.
# The current weather summary for strezhevoy is: (60.73, 77.6, 32, 96, 0, 4.47).
# The current weather summary for vila velha is: (-3.71, -38.6, 80.6, 69, 40, 13.87).
# The current weather summary for constitucion is: (23.99, -104.67, 77, 38, 40, 4.7).
# The current weather summary for lisala is: (2.15, 21.52, 70.11, 97, 48, 2.66).
# The current weather summary for kunigal is: (13.02, 77.02, 66.69, 96, 64, 3).
# Current city object for umzimvubu: not found.
# The current weather summary for santander is: (9.42, 123.33, 83.7, 92, 8, 4.9).
# The current weather summary for sinegorye is: (62.09, 150.53, 21.15, 95, 88, 2.66).
# The current weather summary for nikolskoye is: (59.7, 30.79, 46.4, 75, 0, 4.47).
# The current weather summary for chingirlau is: (51.09, 54.08, 30.87, 76, 0, 2.77).
# The current weather summary for ribeira grande is: (38.52, -28.7, 73.71, 96, 64, 19.89).
# The current weather summary for merauke is: (-8.49, 140.4, 78.12, 94, 76, 14.29).
# The current weather summary for dolinsk is: (47.32, 142.8, 44.6, 87, 0, 4.56).
# The current weather summary for bethel is: (60.79, -161.76, 53.06, 73, 90, 12.75).
# The current weather summary for coquimbo is: (-29.95, -71.34, 55.4, 76, 0, 9.17).
# The current weather summary for necochea is: (-38.55, -58.74, 41.22, 73, 0, 2.89).
# The current weather summary for kloulklubed is: (7.04, 134.26, 84.2, 79, 75, 9.17).
# The current weather summary for cascais is: (38.7, -9.42, 65.97, 49, 0, 4.7).
# The current weather summary for ambon is: (47.55, -2.56, 48.2, 76, 0, 3.36).
# The current weather summary for linjiang is: (41.81, 126.91, 42.93, 89, 0, 3.78).
# The current weather summary for soyo is: (-6.13, 12.37, 73.8, 90, 64, 3).
# The current weather summary for luau is: (-10.7, 22.23, 66.33, 66, 0, 3.11).
# The current weather summary for bluff is: (-23.58, 149.07, 74.34, 40, 0, 11.5).
# The current weather summary for chokurdakh is: (70.62, 147.9, 35.55, 98, 68, 15.3).
# The current weather summary for nishihara is: (35.74, 139.53, 70.11, 51, 1, 5.82).
# The current weather summary for sibu is: (2.29, 111.83, 77, 88, 75, 3.36).
# The current weather summary for kaeo is: (-35.1, 173.78, 58.41, 98, 92, 4.79).
# The current weather summary for aloleng is: (16.13, 119.78, 77.31, 100, 20, 3).
# The current weather summary for hervey bay is: (-25.3, 152.85, 71.19, 85, 0, 16.2).
# The current weather summary for grindavik is: (63.84, -22.43, 42.93, 86, 90, 42.5).
# The current weather summary for hobyo is: (5.35, 48.53, 74.97, 93, 56, 13.29).
# The current weather summary for nome is: (30.04, -94.42, 75.51, 100, 90, 4.7).
# The current weather summary for tres arroyos is: (-38.38, -60.28, 39.06, 42, 0, 4).
# Current city object for gurskoye: not found.
# The current weather summary for severo-kurilsk is: (50.68, 156.12, 47.07, 98, 20, 15.64).
# The current weather summary for umred is: (20.85, 79.32, 75.2, 88, 24, 4.45).
# Current city object for sayanskiy: not found.
# Current city object for sakakah: not found.
# The current weather summary for cabo san lucas is: (22.89, -109.91, 83.21, 70, 75, 12.75).
# Current city object for nizhneyansk: not found.
# The current weather summary for vangaindrano is: (-23.35, 47.6, 60.57, 85, 92, 3.11).
# Current city object for malwan: not found.
# The current weather summary for vaini is: (15.34, 74.49, 68.76, 93, 36, 2.44).
# The current weather summary for port hedland is: (-20.31, 118.58, 78.8, 50, 0, 9.17).
# Current city object for huazolotitlan: not found.
# The current weather summary for yuci is: (37.68, 112.73, 39.2, 93, 0, 2.55).
# The current weather summary for tasiilaq is: (65.61, -37.64, 32, 100, 0, 6.93).
# The current weather summary for jaisalmer is: (26.91, 70.91, 73.44, 44, 0, 6.35).
# The current weather summary for kenai is: (60.55, -151.26, 46.47, 100, 90, 3.67).
# The current weather summary for marawi is: (8, 124.29, 73.98, 97, 48, 2.33).
# The current weather summary for wanaka is: (-44.7, 169.14, 51.21, 58, 64, 4.12).
# The current weather summary for maragogi is: (-9.01, -35.22, 75.51, 82, 92, 8.48).
# The current weather summary for campina grande do sul is: (-25.3, -49.05, 75.2, 60, 20, 2.24).
# The current weather summary for kangaatsiaq is: (68.31, -53.46, 35.01, 100, 88, 16.08).
# The current weather summary for narsaq is: (60.91, -46.05, 33.8, 59, 8, 10.29).
# The current weather summary for neiafu is: (-18.65, -173.98, 78.8, 57, 75, 13.87).
# The current weather summary for maldonado is: (-34.91, -54.96, 51.8, 62, 0, 10.29).
# The current weather summary for belyy yar is: (53.6, 91.39, 48.2, 81, 0, 8.93).
# The current weather summary for hanzhong is: (33.08, 107.03, 50.76, 77, 68, 2.1).
# The current weather summary for les cayes is: (18.19, -73.75, 79.11, 100, 80, 4.23).
# The current weather summary for gondar is: (41.82, -8.78, 60.91, 72, 0, 3.36).
# The current weather summary for majene is: (-3.54, 118.97, 82.17, 98, 0, 21.12).
# The current weather summary for sovetskiy is: (56.76, 48.47, 39.24, 89, 0, 9.82).
# The current weather summary for mandan is: (46.83, -100.89, 48.92, 77, 90, 9.17).
# The current weather summary for kualakapuas is: (-3.01, 114.39, 75.2, 88, 0, 4.7).
# The current weather summary for polunochnoye is: (60.87, 60.43, 37.17, 92, 0, 8.59).
# The current weather summary for tarauaca is: (-8.16, -70.77, 79.56, 89, 32, 2.77).
# The current weather summary for redlands is: (34.06, -117.19, 89.73, 28, 75, 10.29).
# The current weather summary for puerto leguizamo is: (-0.19, -74.78, 82.71, 74, 12, 2.33).
# The current weather summary for avarua is: (-21.21, -159.78, 71.6, 60, 75, 13.87).
# The current weather summary for ullapool is: (57.9, -5.16, 51.84, 100, 92, 25.37).
# The current weather summary for mapiri is: (-15.31, -68.22, 53.46, 95, 8, 1.43).
# Current city object for meyungs: not found.
# The current weather summary for gamba is: (28.28, 88.52, 26.46, 81, 48, 1.99).
# The current weather summary for broome is: (52.47, 1.45, 50.7, 76, 56, 6.93).
# The current weather summary for waingapu is: (-9.65, 120.26, 78.84, 78, 12, 8.59).
# The current weather summary for bafoulabe is: (13.81, -10.83, 77.85, 80, 20, 2.55).
# The current weather summary for komsomolskiy is: (67.55, 63.78, 30.87, 87, 80, 13.29).
# The current weather summary for ucluelet is: (48.94, -125.55, 57.2, 93, 75, 5.82).
# The current weather summary for kabompo is: (-13.6, 24.21, 71.37, 37, 8, 14.74).
# The current weather summary for kastamonu is: (41.38, 33.78, 49.68, 95, 76, 2.33).
# Current city object for temaraia: not found.
# The current weather summary for shelburne is: (44.08, -80.2, 48.2, 81, 90, 6.93).
# The current weather summary for saint george is: (39.45, 22.34, 59, 77, 20, 3.36).
# The current weather summary for half moon bay is: (37.46, -122.43, 76.53, 49, 75, 13.87).
# The current weather summary for shush is: (55.6, 89.45, 47.43, 85, 92, 11.61).
# The current weather summary for muroto is: (33.37, 134.14, 66.2, 63, 75, 6.93).
# The current weather summary for riyadh is: (24.63, 46.72, 77, 17, 0, 4.7).
# Current city object for basyanovskiy: not found.
# The current weather summary for parana is: (-7.52, -72.89, 78.8, 78, 75, 4.7).
# The current weather summary for zhaoyang is: (42.68, 126.03, 47.88, 90, 0, 7.81).
# Current city object for karpuninskiy: not found.
# The current weather summary for conakry is: (9.52, -13.7, 77.85, 100, 88, 6.91).
# The current weather summary for arkadak is: (51.94, 43.49, 32.31, 71, 0, 7.92).
# Current city object for riaba: not found.
# The current weather summary for cidreira is: (-30.17, -50.22, 67.32, 100, 92, 8.48).
# Current city object for potgietersrus: not found.
# The current weather summary for comodoro rivadavia is: (-45.87, -67.48, 53.6, 37, 20, 6.93).
# The current weather summary for talnakh is: (69.49, 88.39, 29.07, 100, 12, 6.8).
# The current weather summary for bara is: (10.41, 10.6, 74.61, 88, 0, 7.81).
# The current weather summary for ilulissat is: (69.22, -51.1, 32, 94, 75, 13.87).
# The current weather summary for te anau is: (-45.41, 167.72, 44.91, 99, 92, 4.68).
# The current weather summary for balabac is: (7.99, 117.06, 80.82, 100, 48, 6.02).
# The current weather summary for kalangala is: (-0.32, 32.29, 69.8, 83, 75, 8.05).
# The current weather summary for gretna is: (55, -3.06, 50, 100, 100, 24.16).
# The current weather summary for jalu is: (29.03, 21.55, 70.02, 43, 0, 5.01).
# The current weather summary for pitea is: (65.32, 21.48, 41, 93, 92, 4.7).
# The current weather summary for tateyama is: (36.66, 137.31, 59, 87, 75, 4.7).
# The current weather summary for severo-yeniseyskiy is: (60.37, 93.04, 38.7, 76, 64, 9.82).
# The current weather summary for gat is: (14.69, -16.54, 82.4, 83, 0, 5.79).
# Current city object for saleaula: not found.
# The current weather summary for ixtapa is: (20.71, -105.21, 87.8, 70, 40, 10.29).
# The current weather summary for carnarvon is: (-30.97, 22.13, 57.69, 23, 12, 10.49).
# Current city object for rungata: not found.
# The current weather summary for lebu is: (8.96, 38.73, 48.69, 72, 0, 5.01).
# The current weather summary for lucapa is: (-8.42, 20.74, 64.35, 93, 36, 2.77).
# The current weather summary for klyuchi is: (52.25, 79.17, 45.99, 93, 92, 3.67).
# The current weather summary for the valley is: (18.22, -63.06, 81.54, 69, 20, 3.36).
# The current weather summary for betare oya is: (5.6, 14.08, 67.59, 99, 92, 4.9).
# The current weather summary for mount isa is: (-20.73, 139.49, 84.2, 28, 24, 19.46).
# The current weather summary for guayaramerin is: (-10.82, -65.36, 79.74, 84, 8, 1.66).
# The current weather summary for cruzeiro do sul is: (-7.63, -72.67, 78.8, 78, 75, 4.7).
# The current weather summary for praia da vitoria is: (38.73, -27.07, 71.6, 83, 40, 18.99).
# The current weather summary for yatou is: (3.63, 9.81, 77, 94, 40, 3.36).
# The current weather summary for kerouane is: (12.23, -12.34, 70.38, 94, 24, 2.33).
# The current weather summary for port shepstone is: (-30.74, 30.45, 68.49, 93, 56, 9.48).
# The current weather summary for evensk is: (61.92, 159.24, 39.51, 100, 88, 22.01).
# The current weather summary for sauda is: (59.65, 6.35, 32.76, 100, 92, 2.44).
# Current city object for marcona: not found.
# The current weather summary for iqaluit is: (63.75, -68.52, 30.2, 68, 75, 6.93).
# The current weather summary for bosanska gradiska is: (45.14, 17.25, 51.8, 100, 75, 3.36).
# The current weather summary for yashan is: (30.81, 118.02, 61.38, 86, 20, 1.21).
# The current weather summary for faya is: (18.39, 42.45, 65.32, 47, 0, 6.93).
# The current weather summary for belaya gora is: (68.54, 146.19, 33.39, 98, 92, 8.7).
# The current weather summary for madang is: (-5.21, 145.81, 81.81, 83, 0, 2.66).
# The current weather summary for saint-joseph is: (43.56, 6.97, 58.5, 76, 0, 3.36).
# The current weather summary for tuxpan is: (19.56, -103.38, 78.8, 88, 75, 13.87).
# Current city object for abiy adi: not found.
# The current weather summary for ulaangom is: (49.98, 92.07, 29.52, 55, 0, 4).
# The current weather summary for esperance is: (10.24, -61.45, 80.6, 88, 20, 6.13).
# The current weather summary for grootfontein is: (-19.56, 18.1, 64.08, 39, 0, 9.37).
# The current weather summary for kandi is: (11.13, 2.93, 72.81, 92, 36, 2.77).
# The current weather summary for gao is: (16.28, -0.04, 83.52, 46, 24, 4.45).
# The current weather summary for mount gambier is: (-37.83, 140.78, 66.24, 66, 48, 7.47).
# The current weather summary for anadyr is: (64.73, 177.51, 48.2, 93, 90, 13.42).
# The current weather summary for amahai is: (-3.31, 129, 80.64, 100, 64, 11.95).
# The current weather summary for mwinilunga is: (-11.73, 24.43, 67.68, 49, 8, 5.01).
# The current weather summary for klaksvik is: (62.23, -6.59, 46.4, 81, 56, 24.16).
# The current weather summary for troitsko-pechorsk is: (62.71, 56.19, 42.57, 95, 92, 8.25).
# The current weather summary for sinnamary is: (5.38, -52.96, 82.17, 94, 56, 11.16).
# The current weather summary for usakos is: (-22, 15.59, 65.43, 65, 24, 2.44).
# The current weather summary for lufilufi is: (-13.87, -171.6, 81, 100, 88, 23.35).
# Current city object for toliary: not found.
# The current weather summary for port lincoln is: (-34.72, 135.86, 62.64, 86, 68, 3.11).
# The current weather summary for mangai is: (-4.07, 19.59, 72.45, 97, 88, 2.77).
# The current weather summary for pevek is: (69.7, 170.27, 44.19, 89, 80, 4.79).
# The current weather summary for itoman is: (26.12, 127.67, 74.66, 57, 0, 6.93).
# The current weather summary for santa cecilia is: (5.35, -76.12, 82.4, 78, 40, 5.82).
# The current weather summary for batticaloa is: (7.71, 81.69, 77.22, 100, 76, 9.48).
# The current weather summary for arlit is: (18.74, 7.39, 80.64, 19, 68, 4.34).
# The current weather summary for ayan is: (40.67, 33.6, 45.45, 96, 36, 2.1).
# The current weather summary for alofi is: (-19.06, -169.92, 77, 61, 75, 24.16).
# The current weather summary for nogliki is: (51.8, 143.14, 46.35, 95, 0, 12.84).
# The current weather summary for kedougou is: (12.56, -12.19, 72.99, 91, 24, 2.89).
# The current weather summary for bitung is: (1.44, 125.19, 80.6, 74, 20, 1.12).
# The current weather summary for faanui is: (-16.48, -151.75, 79.02, 100, 64, 10.71).
# The current weather summary for port-gentil is: (-0.72, 8.78, 78.8, 88, 75, 9.17).
# The current weather summary for barra patuca is: (15.8, -84.28, 79.92, 100, 56, 8.03).
# The current weather summary for vardo is: (39.62, -77.74, 74.62, 83, 5, 4.7).
# Current city object for camana: not found.
# The current weather summary for biltine is: (14.53, 20.93, 82.44, 41, 92, 3.11).
# The current weather summary for salalah is: (17.01, 54.1, 73.4, 73, 0, 3.36).
# The current weather summary for fortuna is: (38.18, -1.13, 69.82, 77, 20, 6.93).
# The current weather summary for baykit is: (61.68, 96.39, 43.02, 96, 92, 9.48).
# The current weather summary for sao jose da coroa grande is: (-8.9, -35.15, 75.51, 82, 92, 8.48).
# The current weather summary for nalut is: (31.86, 10.98, 68.94, 38, 88, 5.01).
# The current weather summary for alice springs is: (-23.7, 133.88, 75.2, 17, 0, 5.82).
# The current weather summary for kavieng is: (-2.57, 150.8, 85.32, 100, 76, 7.81).
# The current weather summary for roros is: (62.57, 11.38, 23, 100, 88, 2.24).
# The current weather summary for hami is: (42.84, 93.51, 48.78, 40, 0, 10.49).
# The current weather summary for buta is: (2.79, 24.73, 74.07, 97, 92, 2.55).
# The current weather summary for kaitangata is: (-46.28, 169.85, 48.42, 99, 92, 20).
# The current weather summary for liverpool is: (53.41, -2.98, 48.87, 93, 75, 5.82).
# The current weather summary for guasdualito is: (7.24, -70.73, 73.4, 100, 75, 8.05).
# The current weather summary for venancio aires is: (-29.61, -52.19, 65.16, 99, 100, 3.67).
# The current weather summary for kinsale is: (51.71, -8.52, 55.4, 93, 75, 11.41).
# The current weather summary for kiruna is: (67.86, 20.23, 32, 100, 92, 3.36).
# The current weather summary for yumen is: (40.29, 97.04, 31.05, 72, 0, 2.1).
# The current weather summary for port elizabeth is: (39.31, -74.98, 73.74, 84, 1, 8.05).
# Current city object for formoso do araguaia: not found.
# The current weather summary for mehnagar is: (25.88, 83.12, 71.55, 76, 0, 4.23).
# The current weather summary for taitung is: (22.76, 121.15, 73.4, 60, 75, 8.05).
# Current city object for samusu: not found.
# The current weather summary for den helder is: (52.96, 4.76, 51.8, 66, 90, 11.41).
# The current weather summary for mpulungu is: (-8.77, 31.12, 61.74, 68, 32, 12.62).
# The current weather summary for reyes is: (-14.3, -67.34, 87.48, 55, 36, 4.68).
# Current city object for felidhoo: not found.
# The current weather summary for avera is: (33.19, -82.53, 78.78, 74, 1, 6.35).
# The current weather summary for ajaccio is: (41.93, 8.74, 57.2, 67, 80, 5.82).
# The current weather summary for udupi is: (13.34, 74.75, 77, 94, 40, 3.36).
# The current weather summary for bethanien is: (-26.5, 17.16, 61.92, 22, 0, 7.58).
# The current weather summary for finschhafen is: (-6.6, 147.85, 80.19, 78, 12, 3).
# The current weather summary for dawei is: (14.07, 98.19, 73.98, 100, 92, 0.65).
# The current weather summary for san patricio is: (-26.98, -56.83, 68.67, 99, 92, 8.25).
# The current weather summary for morondava is: (-20.3, 44.28, 74.07, 85, 0, 7.81).
# Current city object for tabiauea: not found.
# The current weather summary for sola is: (58.89, 5.65, 45.48, 81, 90, 8.05).
# The current weather summary for roald is: (62.58, 6.12, 39.69, 81, 92, 2.24).
# The current weather summary for hefei is: (31.82, 117.22, 59, 82, 0, 2.24).
# The current weather summary for beroroha is: (-21.68, 45.17, 61.92, 72, 0, 5.01).
# The current weather summary for ardmore is: (34.99, -86.85, 77.32, 94, 1, 5.01).
# The current weather summary for muros is: (42.77, -9.06, 53.6, 81, 0, 3.36).
# Current city object for khonuu: not found.
# The current weather summary for pasni is: (25.26, 63.48, 78.12, 96, 0, 5.79).
# The current weather summary for grand gaube is: (-20.01, 57.66, 71.6, 83, 40, 10.29).
# The current weather summary for uray is: (60.13, 64.8, 37.71, 85, 24, 7.92).
# The current weather summary for kamenka is: (53.19, 44.05, 33.12, 83, 0, 5.68).
# Current city object for cheyur: not found.
# The current weather summary for jiuquan is: (39.73, 98.49, 26.19, 56, 0, 3.22).
# The current weather summary for pochutla is: (15.74, -96.47, 86, 70, 75, 11.39).
# The current weather summary for novocheboksarsk is: (56.11, 47.49, 41, 80, 20, 8.95).
# Current city object for sorvag: not found.
# The current weather summary for coahuayana is: (18.62, -100.35, 80.82, 58, 0, 1.54).
# The current weather summary for rio grande is: (-32.03, -52.1, 57.87, 100, 92, 23.02).
# The current weather summary for sitka is: (37.17, -99.65, 84.51, 37, 20, 14.52).
# The current weather summary for tura is: (25.52, 90.21, 71.64, 97, 48, 3.78).
# The current weather summary for san andres is: (13.32, 122.68, 81.54, 100, 76, 11.5).
# Current city object for inderborskiy: not found.
# The current weather summary for nizhniy kuranakh is: (58.84, 125.49, 36.72, 99, 92, 5.46).
# The current weather summary for teeli is: (51.01, 90.2, 26.46, 71, 8, 2.21).
# The current weather summary for dauphin is: (51.15, -100.04, 37.4, 100, 90, 3.36).
# Current city object for louisbourg: not found.
# The current weather summary for marsa matruh is: (31.35, 27.25, 77, 73, 20, 4.79).
# The current weather summary for manokwari is: (-0.87, 134.08, 79.65, 100, 76, 10.71).
# The current weather summary for grand-lahou is: (5.24, -5, 75.33, 91, 48, 5.23).
# The current weather summary for zeya is: (53.74, 127.27, 43.74, 69, 24, 8.25).
# The current weather summary for atar is: (20.52, -13.05, 76.41, 62, 56, 3.56).
# The current weather summary for columbus is: (32.46, -84.99, 82.27, 85, 1, 4.23).
# The current weather summary for ozuluama is: (21.12, -98.35, 74.16, 97, 24, 1.66).
# The current weather summary for acapulco is: (16.86, -99.88, 84.2, 79, 75, 11.41).
# The current weather summary for verkhovazhye is: (60.75, 42.05, 41.22, 93, 36, 10.83).
# Current city object for bolungarvik: not found.
# The current weather summary for pilar is: (-34.46, -58.91, 52.39, 43, 0, 7.14).
# The current weather summary for aklavik is: (68.22, -135.01, 35.6, 64, 20, 9.17).
# The current weather summary for tahe is: (52.34, 124.71, 42.75, 79, 20, 10.27).
# The current weather summary for koulamoutou is: (-1.13, 12.47, 67.59, 99, 100, 2.66).
# The current weather summary for nouakchott is: (18.08, -15.98, 80.64, 94, 0, 13.51).
# The current weather summary for opuwo is: (-18.06, 13.84, 70.29, 31, 0, 7.14).
# The current weather summary for mukhen is: (48.19, 136.14, 46.44, 64, 0, 5.46).
# The current weather summary for mangaratiba is: (-22.96, -44.04, 77, 88, 75, 8.05).
# The current weather summary for douglas is: (58.28, -134.39, 60.93, 6, 20, 10.29).
# The current weather summary for yar-sale is: (66.83, 70.83, 31.95, 100, 8, 5.68).
# The current weather summary for rach gia is: (10.02, 105.08, 74.79, 100, 92, 4.9).
# The current weather summary for bougouni is: (11.42, -7.49, 71.37, 94, 36, 3).
# The current weather summary for indramayu is: (-4.05, 103.78, 69.3, 79, 8, 1.88).
# The current weather summary for baijiantan is: (45.63, 85.18, 52.2, 78, 0, 2.33).
# The current weather summary for boundiali is: (9.53, -6.48, 72.18, 95, 48, 3.11).
# The current weather summary for hofn is: (64.25, -15.21, 41.85, 100, 24, 10.71).
# The current weather summary for xining is: (36.62, 101.77, 29.07, 82, 36, 1.66).
# The current weather summary for nizhniy tsasuchey is: (50.52, 115.13, 44.37, 69, 0, 10.04).
# The current weather summary for aykhal is: (65.95, 111.51, 26.55, 81, 36, 3.89).
# The current weather summary for naron is: (43.52, -8.15, 57.2, 71, 0, 4.7).
# The current weather summary for herat is: (34.35, 62.22, 43.47, 66, 0, 3.67).
# The current weather summary for dunedin is: (-45.87, 170.5, 52.11, 93, 64, 8.81).
# Current city object for korla: not found.
# The current weather summary for xai-xai is: (-25.04, 33.64, 67.95, 100, 0, 11.72).
# Current city object for asayita: not found.
# The current weather summary for kissidougou is: (9.19, -10.1, 69.75, 100, 92, 2.89).
# The current weather summary for beidao is: (34.57, 105.89, 36.63, 80, 0, 1.32).
# Current city object for stornoway: not found.
# The current weather summary for tezu is: (27.93, 96.16, 60.66, 75, 0, 1.88).
# The current weather summary for dongsheng is: (29.72, 112.52, 63.45, 82, 68, 2.89).
# The current weather summary for sokolo is: (14.74, -6.12, 74.61, 79, 44, 1.66).
# The current weather summary for feijo is: (-3.63, -79.92, 68.22, 89, 92, 0.98).
# The current weather summary for uinskoye is: (56.88, 56.58, 41.22, 97, 36, 6.58).
# The current weather summary for zhigansk is: (66.77, 123.37, 31.32, 100, 56, 5.01).
# The current weather summary for arman is: (59.7, 150.17, 41, 60, 20, 11.18).
# The current weather summary for jos is: (9.92, 8.9, 65.79, 87, 20, 2.66).
# The current weather summary for salinopolis is: (-0.61, -47.36, 81.18, 95, 80, 15.75).
# The current weather summary for puerto quijarro is: (-19, -57.72, 86.88, 62, 20, 9.17).
# The current weather summary for mahibadhoo is: (3.78, 72.97, 81.09, 100, 92, 22.57).
# The current weather summary for sorong is: (-0.86, 131.25, 79.65, 100, 76, 6.02).
# The current weather summary for marion is: (35.21, -90.2, 81.32, 74, 1, 4.7).
# Current city object for hire: not found.
# The current weather summary for ternate is: (14.29, 120.72, 82.4, 100, 75, 3.36).
# The current weather summary for northam is: (51.04, -4.21, 52.45, 81, 0, 5.82).
# Current city object for zaplyusye: not found.
# The current weather summary for batagay-alyta is: (67.8, 130.41, 8.91, 58, 0, 3).
# The current weather summary for luohe is: (33.57, 114.03, 59.13, 63, 0, 5.01).
# The current weather summary for progreso is: (-34.68, -56.22, 53.6, 37, 0, 10.29).
# The current weather summary for ust-omchug is: (61.13, 149.63, 21.06, 82, 76, 3.44).
# The current weather summary for anzio is: (41.45, 12.63, 65.53, 52, 40, 16.11).
# The current weather summary for tigil is: (57.8, 158.67, 44.19, 78, 76, 12.39).
# The current weather summary for saint-augustin is: (44.83, -0.61, 49.19, 87, 0, 2.24).
# The current weather summary for moyale is: (3.52, 39.05, 60.48, 80, 0, 6.46).
# The current weather summary for eidsvag is: (62.78, 8.07, 38.3, 86, 48, 8.05).
# The current weather summary for lagoa is: (37.14, -8.45, 73.4, 49, 0, 4.7).
# The current weather summary for kanniyakumari is: (8.08, 77.57, 80.28, 100, 68, 11.05).
# The current weather summary for ancud is: (-41.87, -73.83, 45.45, 95, 88, 6.69).
# The current weather summary for manjacaze is: (-24.71, 33.88, 62.1, 76, 0, 7.36).
# The current weather summary for ueda is: (36.41, 138.25, 60.8, 59, 20, 8.05).
# The current weather summary for encruzilhada do sul is: (-30.54, -52.52, 55.17, 98, 92, 18.54).
# The current weather summary for vestmannaeyjar is: (63.44, -20.27, 43.83, 100, 80, 37.89).
# The current weather summary for myronivka is: (49.66, 30.98, 46.71, 96, 92, 2.66).
# The current weather summary for clyde river is: (70.47, -68.59, 23, 92, 90, 12.75).
# The current weather summary for chapais is: (49.78, -74.86, 35.6, 74, 75, 2.24).
# The current weather summary for kavaratti is: (10.57, 72.64, 80.64, 100, 56, 3.44).
# The current weather summary for ballina is: (54.11, -9.15, 55.89, 98, 92, 15.52).
# The current weather summary for nong ki is: (14.69, 102.54, 73.4, 100, 20, 9.48).
# The current weather summary for bereda is: (43.27, -7.54, 57.2, 71, 0, 4.7).
# Current city object for burica: not found.
# The current weather summary for noyabrsk is: (63.2, 75.45, 27.72, 91, 0, 8.14).
# The current weather summary for toledo is: (10.38, 123.64, 80.6, 88, 40, 2.24).
# Current city object for paucartambo: not found.
# The current weather summary for dera gopipur is: (31.9, 76.22, 63.18, 62, 0, 3.22).
# The current weather summary for kamyshlov is: (56.85, 62.71, 37.08, 93, 8, 10.83).
# The current weather summary for gotsu is: (35.01, 132.22, 60.8, 93, 75, 3.36).
# The current weather summary for anloga is: (5.79, 0.9, 77, 88, 40, 4.7).
# The current weather summary for palimbang is: (14.9, 120.78, 80.01, 88, 75, 2.24).
# The current weather summary for matara is: (-13.74, -72.9, 49.41, 59, 8, 1.88).
# Current city object for alotau: not found.
# The current weather summary for nyurba is: (63.29, 118.35, 37.8, 83, 68, 6.46).
# The current weather summary for dalbandin is: (28.9, 64.41, 50.49, 41, 0, 2.1).
# The current weather summary for neuquen is: (-38.95, -68.06, 53.6, 32, 0, 11.41).
# The current weather summary for mama is: (20.48, -89.36, 78.8, 88, 75, 4.7).
# The current weather summary for bousse is: (49.28, 6.2, 40.98, 86, 0, 2.24).
# The current weather summary for yushu is: (44.84, 126.53, 48.24, 90, 0, 12.06).
# The current weather summary for antequera is: (-24.09, -57.2, 81.09, 71, 44, 4.79).
# The current weather summary for tsiroanomandidy is: (-18.77, 46.05, 53.64, 71, 0, 4.79).
# The current weather summary for itapema is: (-27.09, -48.61, 68, 94, 20, 3.33).
# The current weather summary for tessaoua is: (13.76, 7.99, 77.22, 63, 12, 11.16).
# The current weather summary for vostok is: (46.45, 135.83, 44.91, 68, 0, 2.77).
# The current weather summary for isangel is: (-19.55, 169.27, 71.91, 100, 92, 6.8).
# The current weather summary for dali is: (25.6, 100.24, 53.91, 100, 92, 2.21).
# The current weather summary for floro is: (61.6, 5.03, 42.8, 87, 92, 10.29).
# The current weather summary for katangli is: (51.71, 143.23, 46.35, 95, 0, 12.84).
# Current city object for tanjong sepat: not found.
# The current weather summary for vestmanna is: (62.16, -7.17, 46.4, 81, 88, 24.16).
# The current weather summary for antofagasta is: (-23.65, -70.4, 59, 72, 90, 8.05).
# The current weather summary for jieshi is: (22.82, 115.83, 76.95, 100, 0, 15.97).
# The current weather summary for luderitz is: (-26.65, 15.16, 59.04, 74, 0, 20.22).
# The current weather summary for dores do indaia is: (-19.46, -45.6, 76.59, 51, 88, 9.04).
# The current weather summary for butembo is: (0.12, 29.29, 58.59, 94, 64, 0.76).
# The current weather summary for neropolis is: (-16.41, -49.22, 66.2, 82, 75, 9.17).
# The current weather summary for beterou is: (9.2, 2.26, 71.73, 98, 80, 2.89).
# The current weather summary for sibolga is: (1.74, 98.78, 67.77, 100, 68, 1.43).
# The current weather summary for prince rupert is: (54.32, -130.32, 59, 41, 1, 4.7).
# The current weather summary for loja is: (-4, -79.2, 61.02, 86, 64, 1.43).
# The current weather summary for sairang is: (23.81, 92.66, 73.89, 95, 0, 2.44).
# The current weather summary for kutum is: (14.2, 24.66, 74.34, 24, 8, 9.6).
# The current weather summary for pangkalanbuun is: (-2.68, 111.62, 76.95, 94, 8, 4.23).
# The current weather summary for vryburg is: (-26.96, 24.73, 56.25, 50, 0, 5.46).
# The current weather summary for rancho palos verdes is: (33.75, -118.37, 86.31, 41, 40, 16.11).
# The current weather summary for qaqortoq is: (60.72, -46.03, 33.8, 59, 68, 10.29).
# Current city object for bossembele: not found.
# The current weather summary for gorontalo is: (0.54, 123.06, 81.81, 71, 0, 2.77).
# The current weather summary for pilibanga is: (29.49, 74.08, 68.04, 78, 0, 2.77).
# The current weather summary for loandjili is: (-4.77, 11.87, 77, 83, 20, 4.7).
# The current weather summary for bucerias is: (20.76, -105.33, 87.8, 70, 40, 10.29).
# The current weather summary for sorland is: (67.67, 12.69, 48.24, 100, 64, 7.36).
# The current weather summary for wuwei is: (37.93, 102.64, 39.96, 59, 92, 5.01).
# The current weather summary for singaraja is: (-8.11, 115.08, 80.6, 78, 20, 4.7).
# The current weather summary for morant bay is: (17.88, -76.41, 80.6, 83, 75, 21.92).
# The current weather summary for yeniseysk is: (58.45, 92.17, 46.62, 78, 48, 9.26).
# The current weather summary for la ronge is: (55.1, -105.3, 37.4, 44, 75, 5.82).
# The current weather summary for jacareacanga is: (-6.22, -57.76, 84.42, 57, 68, 3.22).
# The current weather summary for yenagoa is: (4.92, 6.26, 74.97, 97, 88, 7.25).
# Current city object for ozgon: not found.
# The current weather summary for coari is: (-4.09, -63.14, 88.92, 47, 0, 6.69).
# Current city object for ngukurr: not found.
# The current weather summary for penzance is: (50.12, -5.53, 51.8, 81, 20, 10.29).
# The current weather summary for morehead is: (38.18, -83.43, 75.92, 73, 1, 5.01).
# The current weather summary for sambava is: (-14.27, 50.17, 71.19, 100, 88, 15.08).
# The current weather summary for keetmanshoop is: (-26.57, 18.15, 64.89, 19, 0, 7.7).
# The current weather summary for fare is: (-16.7, -151.02, 76.23, 100, 88, 9.82).
# The current weather summary for san carlos is: (9.66, -68.59, 74.25, 90, 48, 3.11).
# The current weather summary for jupiter is: (26.93, -80.09, 83.39, 71, 75, 14.99).
# The current weather summary for riohacha is: (11.54, -72.91, 73.4, 100, 90, 6.93).
# The current weather summary for vilyuysk is: (63.75, 121.63, 40.59, 100, 88, 6.46).
# The current weather summary for palmas bellas is: (9.23, -80.09, 84.2, 74, 40, 2.24).
# The current weather summary for maceio is: (-9.67, -35.74, 71.6, 83, 20, 5.82).
# The current weather summary for diffa is: (13.32, 12.61, 77.94, 63, 0, 3).
# The current weather summary for terrace is: (54.52, -128.61, 57.2, 22, 40, 12.75).
# The current weather summary for anshun is: (26.25, 105.93, 56.52, 67, 76, 4.45).
# The current weather summary for pisco is: (-13.71, -76.2, 64.44, 80, 0, 2.55).
# The current weather summary for savannah bight is: (16.45, -85.85, 83.43, 99, 80, 4.79).
# The current weather summary for atbasar is: (51.81, 68.36, 30.87, 88, 0, 2.89).
# The current weather summary for tautira is: (-17.73, -149.15, 82.4, 65, 40, 6.93).
# The current weather summary for hengshui is: (37.73, 115.7, 61.29, 55, 0, 3).
# The current weather summary for tazovskiy is: (67.47, 78.7, 32.76, 87, 80, 9.04).
# The current weather summary for kieta is: (-6.22, 155.63, 81, 100, 44, 4.45).
# The current weather summary for xichang is: (27.88, 102.25, 47.52, 100, 92, 1.99).
# The current weather summary for bhimunipatnam is: (17.88, 83.43, 74.07, 99, 0, 3.11).
# The current weather summary for gravdal is: (59.79, 5.78, 44.6, 87, 92, 14.99).
# The current weather summary for ampanihy is: (-24.69, 44.75, 57.51, 80, 0, 9.48).
# The current weather summary for uthal is: (25.81, 66.62, 73.89, 90, 92, 3.67).
# The current weather summary for samarai is: (-10.62, 150.67, 76.32, 100, 92, 13.29).
# 500
# 500
# 561

# %%
#print(weather_data)
print(len(weather_data))
# Out:
# 500

# %%
column_names = ["Latitude", "Longitude", "Temperature(F)", "Humidity%", "Clouds%", "Wind Speed(mph)"]
weather = pd.DataFrame(weather_data, index=cities, columns=column_names)
weather.head()
# Out:
#           Latitude  Longitude  Temperature(F)  Humidity%  Clouds%  \
# kurilsk      45.23     147.88           53.64        100       92
# ushuaia     -54.81     -68.31           35.60         69       40
# cururupu     -1.82     -44.87           80.01         79       36
# katsuura     33.93     134.50           66.20         72       20
# mayumba      -3.44      10.65           74.70         99       92
#
#           Wind Speed(mph)
# kurilsk             10.04
# ushuaia             17.22
# cururupu             9.26
# katsuura             5.82
# mayumba              6.46

# %%
# %matplotlib notebook
x_values = weather["Latitude"]
y_temp_values = weather["Temperature(F)"]
plt.scatter(x_values,y_temp_values, c = y_temp_values, edgecolor="black", linewidths=1, marker="o", 
            cmap='plasma',alpha=0.8, label="City")

# Incorporate the other graph properties
plt.style.use('seaborn')
plt.title(f"City Latitude vs. Max Temperature {time.strftime('%m/%d/%Y')}")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-70, 90])
plt.ylim([-10, 110])

# Save the figure
#plt.savefig("WeatherPy_analysis/Latitude_Temperature.png")
#plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# %matplotlib notebook
x_values = weather["Latitude"]
y_humidity_values = weather["Humidity%"]
plt.scatter(x_values,y_humidity_values, c= y_humidity_values, edgecolor="black", linewidths=1, marker="o", 
            cmap='GnBu',alpha=0.8, label="City")


plt.style.use('seaborn')
plt.title(f"City Latitude vs. Humidity % {time.strftime('%m/%d/%Y')}")
plt.ylabel("Humidity %")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-80, 100])
plt.ylim([-5, 125])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# %matplotlib notebook
x_values = weather["Longitude"]
y_humidity_values = weather["Humidity%"]
plt.scatter(x_values,y_humidity_values, c= y_humidity_values, edgecolor="black", linewidths=1, marker="o", 
            cmap='winter',alpha=0.8, label="City")
plt.style.use('seaborn')
plt.title(f"City Longitude vs. Humidity% {time.strftime('%m/%d/%Y')}")
plt.ylabel("Humidity %")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-180, 180])
plt.ylim([0, 110])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# %matplotlib notebook
x_values = weather["Latitude"]
y_clouds_values = weather["Clouds%"]
plt.scatter(x_values,y_clouds_values, c= y_clouds_values, edgecolor="black", linewidths=1, marker="o", 
            cmap='autumn',alpha=0.8, label="City")
plt.style.use('seaborn')
plt.title(f"City Latitude vs. Clouds % {time.strftime('%m/%d/%Y')}")
plt.ylabel("Clouds %")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-70, 90])
plt.ylim([-5, 105])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# %matplotlib notebook
x_values = weather["Latitude"]
y_wind_values = weather["Wind Speed(mph)"]
plt.scatter(x_values,y_wind_values, c= y_wind_values, edgecolor="black", linewidths=1, marker="o", 
            cmap='gist_earth',alpha=0.8, label="City")
plt.style.use('seaborn')
plt.title(f"City Latitude vs. Wind Speed(mph) {time.strftime('%m/%d/%Y')}")
plt.ylabel("Wind Speed(mph)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-70, 90])
plt.ylim([-1, 30])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
